# %%
import numpy as np
import scipy as sp
from scipy import stats
import matplotlib.pyplot as plt
import time
import amt.method as md
import amt.data_loader as dl
import pickle

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
output_folder = '../../results/simulation'
output_figure_folder = '../../figures/figure_simu'
output_file = output_folder + '/simulation_pi1.pickle'
n_hypothesis = 1000
n_rep = 5
alpha = 0.1
n_fMC = 10000
pi1_list = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4]
# pi1_list = np.arange(0.05,0.55,0.1)
n_param = len(pi1_list)
method_list = ['fmc', 'smc50', 'smc100', 'amt']

# %% [markdown]
# # Simulation

# %%
res_dic = {}
for method in method_list:
    res_dic[method] = {}
    res_dic[method]['n_MC_avg'] = np.zeros([n_param, n_rep], dtype=float)
    res_dic[method]['power'] = np.zeros([n_param, n_rep], dtype=float)
    res_dic[method]['fdp'] = np.zeros([n_param, n_rep], dtype=float)
    res_dic[method]['time'] = np.zeros([n_param, n_rep], dtype=float)
    
for i_pi1,pi1 in enumerate(pi1_list):
    for i_rep in range(n_rep):
        print('pi1=%0.2f, i_rep=%d'%(pi1,i_rep))
        # Generate ground truth
        p_exact, h = dl.load_demo_data(n_hypothesis=n_hypothesis, pi1=pi1, 
                                       effect_size=2.5, random_state=i_rep)
        tau_exact = md.bh(p_exact, alpha=alpha)
        h_exact = (p_exact <= tau_exact)
        # fMC p-values and MC samples
        start_time = time.time()
        B, p_fmc, t_fmc = md.get_monte_carlo_sample(p_exact, n_permutation=n_fMC)
        tau_fmc = md.bh(p_fmc, alpha=alpha)
        h_fmc = (p_fmc <= tau_fmc)
        res_dic['fmc']['n_MC_avg'][i_pi1,i_rep] = n_fMC
        res_dic['fmc']['power'][i_pi1,i_rep] = np.sum(h_fmc&h)/np.sum(h)
        res_dic['fmc']['fdp'][i_pi1,i_rep] = np.sum(h_fmc&(~h))/np.sum(h_fmc)
        res_dic['fmc']['time'][i_pi1,i_rep] = time.time()-start_time
        print('# fMC: avg. MC samples = %d, time=%0.2fs'%(np.mean(n_fMC),
                                                          time.time()-start_time))
        print('')
        # AMT 
        start_time = time.time()
        p_hat_ub, p_hat_lb, p_hat, tau_hat, n_amt = md.amt(md.f_sample_dummy, B, n_hypothesis,
                                          alpha=alpha, n_fMC=n_fMC,
                                          verbose=False)
        h_amt = (p_hat_ub <= tau_hat)
        res_dic['amt']['n_MC_avg'][i_pi1,i_rep] = np.mean(n_amt)
        res_dic['amt']['power'][i_pi1,i_rep] = np.sum(h_amt&h)/np.sum(h)
        res_dic['amt']['fdp'][i_pi1,i_rep] = np.sum(h_amt&(~h))/np.sum(h_amt)
        res_dic['amt']['time'][i_pi1,i_rep] = time.time()-start_time
        print('# AMT: avg. MC samples = %0.1f, time=%0.2fs'%(np.mean(n_amt),
                                                             time.time()-start_time))
        print('# D_hat=%d, D_overlap=%d, D_full=%d'%(md.result_compare(h_amt, h_fmc)))
        print('')
        # smc50
        start_time = time.time()
        p_smc, n_smc = md.sMC(B, r=50)
        tau_smc = md.bh(p_smc, alpha=alpha)
        h_smc = (p_smc <= tau_smc)
        res_dic['smc50']['n_MC_avg'][i_pi1,i_rep] = np.mean(n_smc)
        res_dic['smc50']['power'][i_pi1,i_rep] = np.sum(h_smc&h)/np.sum(h)
        res_dic['smc50']['fdp'][i_pi1,i_rep] = np.sum(h_smc&(~h))/np.sum(h_smc)
        res_dic['smc50']['time'][i_pi1,i_rep] = time.time()-start_time
        print('# sMC50: avg. MC samples = %0.1f, time=%0.2fs'%(np.mean(n_smc),
                                                             time.time()-start_time))
        print('# D_hat=%d, D_overlap=%d, D_full=%d'%(md.result_compare(h_smc, h_fmc)))
        print('')
        # smc100
        start_time = time.time()
        p_smc, n_smc = md.sMC(B, r=100)
        tau_smc = md.bh(p_smc, alpha=alpha)
        h_smc = (p_smc <= tau_smc)
        res_dic['smc100']['n_MC_avg'][i_pi1,i_rep] = np.mean(n_smc)
        res_dic['smc100']['power'][i_pi1,i_rep] = np.sum(h_smc&h)/np.sum(h)
        res_dic['smc100']['fdp'][i_pi1,i_rep] = np.sum(h_smc&(~h))/np.sum(h_smc)
        res_dic['smc100']['time'][i_pi1,i_rep] = time.time()-start_time
        print('# sMC100: avg. MC samples = %0.1f, time=%0.2fs'%(np.mean(n_smc),
                                                             time.time()-start_time))
        print('# D_hat=%d, D_overlap=%d, D_full=%d'%(md.result_compare(h_smc, h_fmc)))
        print('')
with open(output_file, "wb") as f:
    pickle.dump(res_dic, f)
# Out:
# pi1=0.05, i_rep=0
# # fMC: avg. MC samples = 10000, time=2.01s
#
# # AMT: avg. MC samples = 541.3, time=0.05s
# # D_hat=17, D_overlap=17, D_full=17
#
# # sMC50: avg. MC samples = 613.8, time=0.16s
# # D_hat=17, D_overlap=17, D_full=17
#
# # sMC100: avg. MC samples = 906.9, time=0.16s
# # D_hat=17, D_overlap=17, D_full=17
#
# pi1=0.05, i_rep=1
# # fMC: avg. MC samples = 10000, time=2.07s
#
# # AMT: avg. MC samples = 507.0, time=0.05s
# # D_hat=10, D_overlap=10, D_full=10
#
# # sMC50: avg. MC samples = 601.7, time=0.20s
# # D_hat=10, D_overlap=10, D_full=10
#
# # sMC100: avg. MC samples = 904.0, time=0.19s
# # D_hat=10, D_overlap=10, D_full=10
#
# pi1=0.05, i_rep=2
# # fMC: avg. MC samples = 10000, time=2.07s
#
# # AMT: avg. MC samples = 601.0, time=0.05s
# # D_hat=20, D_overlap=20, D_full=20
#
# # sMC50: avg. MC samples = 638.6, time=0.20s
# # D_hat=20, D_overlap=20, D_full=20
#
# # sMC100: avg. MC samples = 936.5, time=0.20s
# # D_hat=20, D_overlap=20, D_full=20
#
# pi1=0.05, i_rep=3
# # fMC: avg. MC samples = 10000, time=2.03s
#
# # AMT: avg. MC samples = 518.9, time=0.05s
# # D_hat=22, D_overlap=22, D_full=22
#
# # sMC50: avg. MC samples = 597.6, time=0.21s
# # D_hat=22, D_overlap=22, D_full=22
#
# # sMC100: avg. MC samples = 887.8, time=0.23s
# # D_hat=22, D_overlap=22, D_full=22
#
# pi1=0.05, i_rep=4
# # fMC: avg. MC samples = 10000, time=2.04s
#
# # AMT: avg. MC samples = 426.6, time=0.05s
# # D_hat=8, D_overlap=8, D_full=8
#
# # sMC50: avg. MC samples = 544.8, time=0.21s
# # D_hat=8, D_overlap=8, D_full=8
#
# # sMC100: avg. MC samples = 844.8, time=0.20s
# # D_hat=8, D_overlap=8, D_full=8
#
# pi1=0.10, i_rep=0
# # fMC: avg. MC samples = 10000, time=2.04s
#
# # AMT: avg. MC samples = 922.8, time=0.08s
# # D_hat=54, D_overlap=54, D_full=54
#
# # sMC50: avg. MC samples = 904.1, time=0.21s
# # D_hat=54, D_overlap=54, D_full=54
#
# # sMC100: avg. MC samples = 1236.2, time=0.23s
# # D_hat=54, D_overlap=54, D_full=54
#
# pi1=0.10, i_rep=1
# # fMC: avg. MC samples = 10000, time=2.08s
#
# # AMT: avg. MC samples = 918.7, time=0.07s
# # D_hat=54, D_overlap=54, D_full=54
#
# # sMC50: avg. MC samples = 914.5, time=0.19s
# # D_hat=54, D_overlap=54, D_full=54
#
# # sMC100: avg. MC samples = 1256.4, time=0.19s
# # D_hat=54, D_overlap=54, D_full=54
#
# pi1=0.10, i_rep=2
# # fMC: avg. MC samples = 10000, time=2.01s
#
# # AMT: avg. MC samples = 992.4, time=0.07s
# # D_hat=42, D_overlap=42, D_full=42
#
# # sMC50: avg. MC samples = 892.2, time=0.20s
# # D_hat=42, D_overlap=42, D_full=42
#
# # sMC100: avg. MC samples = 1231.0, time=0.20s
# # D_hat=42, D_overlap=42, D_full=42
#
# pi1=0.10, i_rep=3
# # fMC: avg. MC samples = 10000, time=2.02s
#
# # AMT: avg. MC samples = 851.9, time=0.07s
# # D_hat=60, D_overlap=60, D_full=60
#
# # sMC50: avg. MC samples = 946.0, time=0.23s
# # D_hat=60, D_overlap=58, D_full=60
#
# # sMC100: avg. MC samples = 1256.0, time=0.24s
# # D_hat=60, D_overlap=60, D_full=60
#
# pi1=0.10, i_rep=4
# # fMC: avg. MC samples = 10000, time=2.00s
#
# # AMT: avg. MC samples = 889.9, time=0.07s
# # D_hat=37, D_overlap=37, D_full=37
#
# # sMC50: avg. MC samples = 863.5, time=0.20s
# # D_hat=37, D_overlap=37, D_full=37
#
# # sMC100: avg. MC samples = 1208.7, time=0.20s
# # D_hat=37, D_overlap=37, D_full=37
#
# pi1=0.15, i_rep=0
# # fMC: avg. MC samples = 10000, time=1.94s
#
# # AMT: avg. MC samples = 1100.9, time=0.08s
# # D_hat=79, D_overlap=79, D_full=79
#
# # sMC50: avg. MC samples = 1123.5, time=0.15s
# # D_hat=78, D_overlap=77, D_full=79
#
# # sMC100: avg. MC samples = 1498.4, time=0.14s
# # D_hat=79, D_overlap=79, D_full=79
#
# pi1=0.15, i_rep=1
# # fMC: avg. MC samples = 10000, time=1.95s
#
# # AMT: avg. MC samples = 1104.8, time=0.08s
# # D_hat=96, D_overlap=96, D_full=96
#
# # sMC50: avg. MC samples = 1241.3, time=0.15s
# # D_hat=95, D_overlap=95, D_full=96
#
# # sMC100: avg. MC samples = 1603.3, time=0.14s
# # D_hat=96, D_overlap=96, D_full=96
#
# pi1=0.15, i_rep=2
# # fMC: avg. MC samples = 10000, time=2.10s
#
# # AMT: avg. MC samples = 1116.7, time=0.08s
# # D_hat=88, D_overlap=88, D_full=88
#
# # sMC50: avg. MC samples = 1181.3, time=0.15s
# # D_hat=89, D_overlap=88, D_full=88
#
# # sMC100: avg. MC samples = 1552.6, time=0.14s
# # D_hat=88, D_overlap=88, D_full=88
#
# pi1=0.15, i_rep=3
# # fMC: avg. MC samples = 10000, time=2.05s
#
# # AMT: avg. MC samples = 957.6, time=0.08s
# # D_hat=97, D_overlap=97, D_full=97
#
# # sMC50: avg. MC samples = 1210.1, time=0.15s
# # D_hat=97, D_overlap=96, D_full=97
#
# # sMC100: avg. MC samples = 1549.6, time=0.15s
# # D_hat=97, D_overlap=97, D_full=97
#
# pi1=0.15, i_rep=4
# # fMC: avg. MC samples = 10000, time=1.95s
#
# # AMT: avg. MC samples = 1110.5, time=0.07s
# # D_hat=96, D_overlap=96, D_full=96
#
# # sMC50: avg. MC samples = 1192.8, time=0.14s
# # D_hat=96, D_overlap=95, D_full=96
#
# # sMC100: avg. MC samples = 1581.7, time=0.14s
# # D_hat=96, D_overlap=96, D_full=96
#
# pi1=0.20, i_rep=0
# # fMC: avg. MC samples = 10000, time=1.92s
#
# # AMT: avg. MC samples = 1200.3, time=0.08s
# # D_hat=136, D_overlap=136, D_full=136
#
# # sMC50: avg. MC samples = 1464.6, time=0.14s
# # D_hat=137, D_overlap=135, D_full=136
#
# # sMC100: avg. MC samples = 1875.1, time=0.14s
# # D_hat=134, D_overlap=134, D_full=136
#
# pi1=0.20, i_rep=1
# # fMC: avg. MC samples = 10000, time=1.91s
#
# # AMT: avg. MC samples = 1152.5, time=0.08s
# # D_hat=151, D_overlap=151, D_full=151
#
# # sMC50: avg. MC samples = 1561.7, time=0.15s
# # D_hat=148, D_overlap=148, D_full=151
#
# # sMC100: avg. MC samples = 1961.1, time=0.18s
# # D_hat=146, D_overlap=146, D_full=151
#
# pi1=0.20, i_rep=2
# # fMC: avg. MC samples = 10000, time=1.93s
#
# # AMT: avg. MC samples = 1137.8, time=0.08s
# # D_hat=142, D_overlap=142, D_full=142
#
# # sMC50: avg. MC samples = 1474.8, time=0.14s
# # D_hat=143, D_overlap=140, D_full=142
#
# # sMC100: avg. MC samples = 1879.6, time=0.14s
# # D_hat=143, D_overlap=142, D_full=142
#
# pi1=0.20, i_rep=3
# # fMC: avg. MC samples = 10000, time=1.92s
#
# # AMT: avg. MC samples = 1106.7, time=0.08s
# # D_hat=133, D_overlap=133, D_full=133
#
# # sMC50: avg. MC samples = 1498.1, time=0.14s
# # D_hat=128, D_overlap=128, D_full=133
#
# # sMC100: avg. MC samples = 1874.7, time=0.14s
# # D_hat=135, D_overlap=133, D_full=133
#
# pi1=0.20, i_rep=4
# # fMC: avg. MC samples = 10000, time=1.94s
#
# # AMT: avg. MC samples = 1271.6, time=0.08s
# # D_hat=136, D_overlap=136, D_full=136
#
# # sMC50: avg. MC samples = 1494.0, time=0.14s
# # D_hat=132, D_overlap=131, D_full=136
#
# # sMC100: avg. MC samples = 1920.0, time=0.14s
# # D_hat=136, D_overlap=134, D_full=136
#
# pi1=0.25, i_rep=0
# # fMC: avg. MC samples = 10000, time=1.89s
#
# # AMT: avg. MC samples = 1288.7, time=0.09s
# # D_hat=179, D_overlap=179, D_full=179
#
# # sMC50: avg. MC samples = 1742.1, time=0.14s
# # D_hat=183, D_overlap=179, D_full=179
#
# # sMC100: avg. MC samples = 2204.9, time=0.14s
# # D_hat=178, D_overlap=178, D_full=179
#
# pi1=0.25, i_rep=1
# # fMC: avg. MC samples = 10000, time=1.89s
#
# # AMT: avg. MC samples = 1190.7, time=0.09s
# # D_hat=197, D_overlap=197, D_full=197
#
# # sMC50: avg. MC samples = 1844.5, time=0.14s
# # D_hat=190, D_overlap=190, D_full=197
#
# # sMC100: avg. MC samples = 2281.0, time=0.14s
# # D_hat=193, D_overlap=192, D_full=197
#
# pi1=0.25, i_rep=2
# # fMC: avg. MC samples = 10000, time=1.89s
#
# # AMT: avg. MC samples = 1200.9, time=0.08s
# # D_hat=179, D_overlap=179, D_full=179
#
# # sMC50: avg. MC samples = 1739.1, time=0.14s
# # D_hat=184, D_overlap=177, D_full=179
#
# # sMC100: avg. MC samples = 2178.4, time=0.14s
# # D_hat=181, D_overlap=178, D_full=179
#
# pi1=0.25, i_rep=3
# # fMC: avg. MC samples = 10000, time=1.88s
#
# # AMT: avg. MC samples = 1195.7, time=0.08s
# # D_hat=180, D_overlap=180, D_full=180
#
# # sMC50: avg. MC samples = 1792.6, time=0.14s
# # D_hat=176, D_overlap=176, D_full=180
#
# # sMC100: avg. MC samples = 2216.1, time=0.13s
# # D_hat=179, D_overlap=179, D_full=180
#
# pi1=0.25, i_rep=4
# # fMC: avg. MC samples = 10000, time=1.82s
#
# # AMT: avg. MC samples = 1352.3, time=0.09s
# # D_hat=179, D_overlap=179, D_full=179
#
# # sMC50: avg. MC samples = 1782.6, time=0.14s
# # D_hat=178, D_overlap=175, D_full=179
#
# # sMC100: avg. MC samples = 2244.2, time=0.13s
# # D_hat=181, D_overlap=179, D_full=179
#
# pi1=0.30, i_rep=0
# # fMC: avg. MC samples = 10000, time=1.77s
#
# # AMT: avg. MC samples = 1350.4, time=0.09s
# # D_hat=216, D_overlap=216, D_full=216
#
# # sMC50: avg. MC samples = 1970.1, time=0.14s
# # D_hat=221, D_overlap=216, D_full=216
#
# # sMC100: avg. MC samples = 2478.1, time=0.13s
# # D_hat=219, D_overlap=216, D_full=216
#
# pi1=0.30, i_rep=1
# # fMC: avg. MC samples = 10000, time=1.79s
#
# # AMT: avg. MC samples = 1281.1, time=0.09s
# # D_hat=236, D_overlap=236, D_full=236
# # sMC50: avg. MC samples = 2120.8, time=0.14s
# # D_hat=235, D_overlap=233, D_full=236
#
# # sMC100: avg. MC samples = 2602.2, time=0.13s
# # D_hat=235, D_overlap=234, D_full=236
#
# pi1=0.30, i_rep=2
# # fMC: avg. MC samples = 10000, time=1.74s
#
# # AMT: avg. MC samples = 1229.2, time=0.07s
# # D_hat=221, D_overlap=221, D_full=221
#
# # sMC50: avg. MC samples = 1990.6, time=0.12s
# # D_hat=223, D_overlap=220, D_full=221
#
# # sMC100: avg. MC samples = 2476.2, time=0.12s
# # D_hat=225, D_overlap=221, D_full=221
#
# pi1=0.30, i_rep=3
# # fMC: avg. MC samples = 10000, time=1.52s
#
# # AMT: avg. MC samples = 1291.0, time=0.08s
# # D_hat=223, D_overlap=223, D_full=223
#
# # sMC50: avg. MC samples = 2100.3, time=0.12s
# # D_hat=219, D_overlap=218, D_full=223
#
# # sMC100: avg. MC samples = 2541.5, time=0.12s
# # D_hat=219, D_overlap=219, D_full=223
#
# pi1=0.30, i_rep=4
# # fMC: avg. MC samples = 10000, time=1.58s
#
# # AMT: avg. MC samples = 1367.1, time=0.08s
# # D_hat=229, D_overlap=229, D_full=229
#
# # sMC50: avg. MC samples = 2111.6, time=0.12s
# # D_hat=235, D_overlap=226, D_full=229
#
# # sMC100: avg. MC samples = 2597.3, time=0.12s
# # D_hat=229, D_overlap=228, D_full=229
#
# pi1=0.35, i_rep=0
# # fMC: avg. MC samples = 10000, time=1.68s
#
# # AMT: avg. MC samples = 1370.8, time=0.10s
# # D_hat=261, D_overlap=261, D_full=261
#
# # sMC50: avg. MC samples = 2251.7, time=0.16s
# # D_hat=260, D_overlap=257, D_full=261
#
# # sMC100: avg. MC samples = 2770.9, time=0.17s
# # D_hat=264, D_overlap=261, D_full=261
#
# pi1=0.35, i_rep=1
# # fMC: avg. MC samples = 10000, time=1.94s
#
# # AMT: avg. MC samples = 1243.2, time=0.11s
# # D_hat=289, D_overlap=289, D_full=289
#
# # sMC50: avg. MC samples = 2419.8, time=0.16s
# # D_hat=287, D_overlap=285, D_full=289
#
# # sMC100: avg. MC samples = 2943.7, time=0.16s
# # D_hat=286, D_overlap=285, D_full=289
#
# pi1=0.35, i_rep=2
# # fMC: avg. MC samples = 10000, time=1.92s
#
# # AMT: avg. MC samples = 1278.9, time=0.09s
# # D_hat=266, D_overlap=266, D_full=266
#
# # sMC50: avg. MC samples = 2273.0, time=0.14s
# # D_hat=262, D_overlap=260, D_full=266
#
# # sMC100: avg. MC samples = 2815.6, time=0.14s
# # D_hat=268, D_overlap=265, D_full=266
#
# pi1=0.35, i_rep=3
# # fMC: avg. MC samples = 10000, time=1.93s
#
# # AMT: avg. MC samples = 1346.1, time=0.10s
# # D_hat=267, D_overlap=267, D_full=267
#
# # sMC50: avg. MC samples = 2410.9, time=0.15s
# # D_hat=265, D_overlap=264, D_full=267
#
# # sMC100: avg. MC samples = 2866.7, time=0.14s
# # D_hat=264, D_overlap=263, D_full=267
#
# pi1=0.35, i_rep=4
# # fMC: avg. MC samples = 10000, time=1.96s
#
# # AMT: avg. MC samples = 1329.6, time=0.09s
# # D_hat=283, D_overlap=283, D_full=283
#
# # sMC50: avg. MC samples = 2420.7, time=0.16s
# # D_hat=282, D_overlap=277, D_full=283
#
# # sMC100: avg. MC samples = 2925.1, time=0.15s
# # D_hat=282, D_overlap=280, D_full=283
#
# pi1=0.40, i_rep=0
# # fMC: avg. MC samples = 10000, time=2.01s
#
# # AMT: avg. MC samples = 1413.8, time=0.12s
# # D_hat=312, D_overlap=312, D_full=312
#
# # sMC50: avg. MC samples = 2538.3, time=0.16s
# # D_hat=312, D_overlap=307, D_full=312
#
# # sMC100: avg. MC samples = 3107.6, time=0.15s
# # D_hat=308, D_overlap=308, D_full=312
#
# pi1=0.40, i_rep=1
# # fMC: avg. MC samples = 10000, time=1.89s
#
# # AMT: avg. MC samples = 1280.5, time=0.10s
# # D_hat=326, D_overlap=326, D_full=326
#
# # sMC50: avg. MC samples = 2694.8, time=0.16s
# # D_hat=331, D_overlap=326, D_full=326
#
# # sMC100: avg. MC samples = 3252.7, time=0.16s
# # D_hat=331, D_overlap=326, D_full=326
#
# pi1=0.40, i_rep=2
# # fMC: avg. MC samples = 10000, time=1.90s
#
# # AMT: avg. MC samples = 1242.2, time=0.12s
# # D_hat=317, D_overlap=317, D_full=317
#
# # sMC50: avg. MC samples = 2555.3, time=0.16s
# # D_hat=316, D_overlap=312, D_full=317
#
# # sMC100: avg. MC samples = 3146.7, time=0.14s
# # D_hat=316, D_overlap=315, D_full=317
#
# pi1=0.40, i_rep=3
# # fMC: avg. MC samples = 10000, time=1.94s
#
# # AMT: avg. MC samples = 1363.9, time=0.11s
# # D_hat=322, D_overlap=322, D_full=322
#
# # sMC50: avg. MC samples = 2739.2, time=0.14s
# # D_hat=318, D_overlap=312, D_full=322
#
# # sMC100: avg. MC samples = 3229.1, time=0.14s
# # D_hat=323, D_overlap=318, D_full=322
#
# pi1=0.40, i_rep=4
# # fMC: avg. MC samples = 10000, time=1.87s
#
# # AMT: avg. MC samples = 1346.5, time=0.10s
# # D_hat=338, D_overlap=338, D_full=338
#
# # sMC50: avg. MC samples = 2702.3, time=0.14s
# # D_hat=334, D_overlap=332, D_full=338
#
# # sMC100: avg. MC samples = 3267.6, time=0.14s
# # D_hat=335, D_overlap=335, D_full=338

# %% [markdown]
# # Generate figures

# %%
with open(output_file, 'rb')as f:
    res_dic = pickle.load(f)

# %%
# Generate the figures
output_fig_file = output_figure_folder+'/figure_alt_prop'
# method_list = ['fmc', 'smc100', 'smc50', 'amt']
# method_dic = {'fmc':'fMC', 'smc50':'sMC (r=50)', 
#               'smc100':'sMC (r=100)', 'amt':'AMT'}
# marker_list = ['o', 'v', '^', '*', 'h', 'd']
# color_list = ['C0', 'C3', 'C1', 'C2', 'C5', 'C8']
method_list = ['fmc', 'smc100', 'amt']
method_dic = {'fmc':'fMC', 'smc50':'sMC (r=50)', 
              'smc100':'sMC', 'amt':'AMT'}
marker_list = ['o', 'v', '^', '*', 'h', 'd']
color_list = ['C0', 'C3', 'C2', 'C1', 'C5', 'C8']
# plt.figure()
plt.figure(figsize=(5,5))
for i_method,method in enumerate(method_list):
    y_val = np.mean(res_dic[method]['n_MC_avg'], axis=1)
    temp = np.std(res_dic[method]['n_MC_avg'], axis=1) / np.sqrt(n_rep) * 1.96
    y_err = np.zeros([2, n_param], dtype=float) 
    y_err[0,:] = np.log10(y_val) - np.log10(y_val-temp) 
    y_err[1,:] = np.log10(y_val+temp) - np.log10(y_val)
    plt.errorbar(pi1_list, np.log10(y_val), yerr=y_err, label=method_dic[method],\
                 capsize=4, elinewidth = 1.5, linewidth=1.5,\
                 color = color_list[i_method], marker = marker_list[i_method],\
                 markersize = 6, alpha=0.8)
plt.grid()
plt.xticks(fontsize=12)
# y_val = [2.5, 3, 3.5, 4]
y_val = [2.7, 3, 3.3, 3.7, 4]
y_tick = []
for y in y_val:
    temp_str = '%0.1e'%(10**y)
#     y_tick.append(temp_str.replace('+0', ''))
    y_tick.append(temp_str.replace('+0', '').replace('.0e','e'))
plt.yticks(y_val, y_tick, rotation= 0, fontsize=12)
plt.legend(fontsize=12, loc='upper left')
plt.xlabel('Alternative proportion', fontsize=14)
# plt.ylabel('log10 average MC samples', fontsize=12)
plt.ylabel('Avg. MC samples per hypothesis', fontsize=14)
plt.tight_layout()
plt.savefig(output_fig_file+'.png')
plt.savefig(output_fig_file+'.pdf')
plt.show()

# %% [markdown]
# # Old code

# %%
# Generate the figures
marker_list = ['o', 'v', '^', '*', 'h', 'd']
color_list = ['C1', 'C2', 'C3', 'C0', 'C5', 'C8']
plt.figure()
for i_method,method in enumerate(method_list):
    y_val = np.mean(res_dic[method]['power'], axis=1)
    y_err = np.std(res_dic[method]['power'], axis=1) / np.sqrt(n_rep) * 1.96
    plt.errorbar(pi1_list, y_val, yerr=y_err, label=method,\
                 capsize=4, elinewidth = 1.5, linewidth=1.5,\
                 color = color_list[i_method], marker = marker_list[i_method],\
                 markersize = 6, alpha=0.8)
plt.legend()
plt.show()

# %%
# Generate the figures
marker_list = ['o', 'v', '^', '*', 'h', 'd']
color_list = ['C1', 'C2', 'C3', 'C0', 'C5', 'C8']
plt.figure()
for i_method,method in enumerate(method_list):
    y_val = np.mean(res_dic[method]['fdp'], axis=1)
    y_err = np.std(res_dic[method]['fdp'], axis=1) / np.sqrt(n_rep) * 1.96
    plt.errorbar(pi1_list, y_val, yerr=y_err, label=method,\
                 capsize=4, elinewidth = 1.5, linewidth=1.5,\
                 color = color_list[i_method], marker = marker_list[i_method],\
                 markersize = 6, alpha=0.8)
plt.legend()
plt.show()
