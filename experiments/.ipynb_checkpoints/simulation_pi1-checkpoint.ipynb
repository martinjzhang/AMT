# %%
import numpy as np
import scipy as sp
from scipy import stats
import matplotlib.pyplot as plt
import time
import amt.method as md
import amt.data_loader as dl
import pickle

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
output_folder = '/home/martin/adapative_MC_test/results/simulation'
output_figure_folder = '/home/martin/adapative_MC_test/figures/figure_simu'
output_file = output_folder + '/simulation_pi1.pickle'
n_hypothesis = 1000
n_rep = 5
alpha = 0.1
n_fMC = 10000
pi1_list = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4]
# pi1_list = np.arange(0.05,0.55,0.1)
n_param = len(pi1_list)
method_list = ['fmc', 'smc50', 'smc100', 'amt']

# %% [markdown]
# # Simulation

# %%
res_dic = {}
for method in method_list:
    res_dic[method] = {}
    res_dic[method]['n_MC_avg'] = np.zeros([n_param, n_rep], dtype=float)
    res_dic[method]['power'] = np.zeros([n_param, n_rep], dtype=float)
    res_dic[method]['fdp'] = np.zeros([n_param, n_rep], dtype=float)
    res_dic[method]['time'] = np.zeros([n_param, n_rep], dtype=float)
    
for i_pi1,pi1 in enumerate(pi1_list):
    for i_rep in range(n_rep):
        print('pi1=%0.2f, i_rep=%d'%(pi1,i_rep))
        # Generate ground truth
        p_exact, h = dl.load_demo_data(n_hypothesis=n_hypothesis, pi1=pi1, 
                                       effect_size=2.5, random_state=i_rep)
        tau_exact = md.bh(p_exact, alpha=alpha)
        h_exact = (p_exact <= tau_exact)
        # fMC p-values and MC samples
        start_time = time.time()
        B, p_fmc, t_fmc = md.get_monte_carlo_sample(p_exact, n_permutation=n_fMC)
        tau_fmc = md.bh(p_fmc, alpha=alpha)
        h_fmc = (p_fmc <= tau_fmc)
        res_dic['fmc']['n_MC_avg'][i_pi1,i_rep] = n_fMC
        res_dic['fmc']['power'][i_pi1,i_rep] = np.sum(h_fmc&h)/np.sum(h)
        res_dic['fmc']['fdp'][i_pi1,i_rep] = np.sum(h_fmc&(~h))/np.sum(h_fmc)
        res_dic['fmc']['time'][i_pi1,i_rep] = time.time()-start_time
        print('# fMC: avg. MC samples = %d, time=%0.2fs'%(np.mean(n_fMC),
                                                          time.time()-start_time))
        print('')
        # AMT 
        start_time = time.time()
        p_hat_ub, p_hat, tau_hat, n_amt = md.amt(md.f_sample_dummy, B, n_hypothesis,
                                          alpha=alpha, n_fMC=n_fMC,
                                          verbose=False)
        h_amt = (p_hat_ub <= tau_hat)
        res_dic['amt']['n_MC_avg'][i_pi1,i_rep] = np.mean(n_amt)
        res_dic['amt']['power'][i_pi1,i_rep] = np.sum(h_amt&h)/np.sum(h)
        res_dic['amt']['fdp'][i_pi1,i_rep] = np.sum(h_amt&(~h))/np.sum(h_amt)
        res_dic['amt']['time'][i_pi1,i_rep] = time.time()-start_time
        print('# AMT: avg. MC samples = %0.1f, time=%0.2fs'%(np.mean(n_amt),
                                                             time.time()-start_time))
        print('# D_hat=%d, D_overlap=%d, D_full=%d'%(md.result_compare(h_amt, h_fmc)))
        print('')
        # smc50
        start_time = time.time()
        p_smc, n_smc = md.sMC(B, r=50)
        tau_smc = md.bh(p_smc, alpha=alpha)
        h_smc = (p_smc <= tau_smc)
        res_dic['smc50']['n_MC_avg'][i_pi1,i_rep] = np.mean(n_smc)
        res_dic['smc50']['power'][i_pi1,i_rep] = np.sum(h_smc&h)/np.sum(h)
        res_dic['smc50']['fdp'][i_pi1,i_rep] = np.sum(h_smc&(~h))/np.sum(h_smc)
        res_dic['smc50']['time'][i_pi1,i_rep] = time.time()-start_time
        print('# sMC50: avg. MC samples = %0.1f, time=%0.2fs'%(np.mean(n_smc),
                                                             time.time()-start_time))
        print('# D_hat=%d, D_overlap=%d, D_full=%d'%(md.result_compare(h_smc, h_fmc)))
        print('')
        # smc100
        start_time = time.time()
        p_smc, n_smc = md.sMC(B, r=100)
        tau_smc = md.bh(p_smc, alpha=alpha)
        h_smc = (p_smc <= tau_smc)
        res_dic['smc100']['n_MC_avg'][i_pi1,i_rep] = np.mean(n_smc)
        res_dic['smc100']['power'][i_pi1,i_rep] = np.sum(h_smc&h)/np.sum(h)
        res_dic['smc100']['fdp'][i_pi1,i_rep] = np.sum(h_smc&(~h))/np.sum(h_smc)
        res_dic['smc100']['time'][i_pi1,i_rep] = time.time()-start_time
        print('# sMC100: avg. MC samples = %0.1f, time=%0.2fs'%(np.mean(n_smc),
                                                             time.time()-start_time))
        print('# D_hat=%d, D_overlap=%d, D_full=%d'%(md.result_compare(h_smc, h_fmc)))
        print('')
with open(output_file, "wb") as f:
    pickle.dump(res_dic, f)
# Out:
# pi1=0.05, i_rep=0
# # fMC: avg. MC samples = 20000, time=4.45s
#
# # AMT: avg. MC samples = 843.1, time=0.08s
# # D_hat=16, D_overlap=16, D_full=16
#
# # sMC50: avg. MC samples = 862.1, time=0.47s
# # D_hat=16, D_overlap=16, D_full=16
#
# # sMC100: avg. MC samples = 1231.7, time=0.47s
# # D_hat=16, D_overlap=16, D_full=16
#
# pi1=0.05, i_rep=1
# # fMC: avg. MC samples = 20000, time=4.23s
#
# # AMT: avg. MC samples = 783.5, time=0.07s
# # D_hat=10, D_overlap=10, D_full=10
#
# # sMC50: avg. MC samples = 821.8, time=0.46s
# # D_hat=10, D_overlap=10, D_full=10
#
# # sMC100: avg. MC samples = 1212.0, time=0.49s
# # D_hat=10, D_overlap=10, D_full=10
#
# pi1=0.05, i_rep=2
# # fMC: avg. MC samples = 20000, time=4.20s
#
# # AMT: avg. MC samples = 934.6, time=0.06s
# # D_hat=20, D_overlap=20, D_full=20
#
# # sMC50: avg. MC samples = 870.9, time=0.50s
# # D_hat=20, D_overlap=20, D_full=20
#
# # sMC100: avg. MC samples = 1293.1, time=0.48s
# # D_hat=20, D_overlap=20, D_full=20
#
# pi1=0.05, i_rep=3
# # fMC: avg. MC samples = 20000, time=4.31s
#
# # AMT: avg. MC samples = 768.6, time=0.07s
# # D_hat=21, D_overlap=21, D_full=21
#
# # sMC50: avg. MC samples = 841.2, time=0.43s
# # D_hat=21, D_overlap=21, D_full=21
#
# # sMC100: avg. MC samples = 1200.9, time=0.43s
# # D_hat=21, D_overlap=21, D_full=21
#
# pi1=0.05, i_rep=4
# # fMC: avg. MC samples = 20000, time=4.13s
#
# # AMT: avg. MC samples = 636.1, time=0.05s
# # D_hat=8, D_overlap=8, D_full=8
#
# # sMC50: avg. MC samples = 721.7, time=0.44s
# # D_hat=8, D_overlap=8, D_full=8
#
# # sMC100: avg. MC samples = 1093.5, time=0.47s
# # D_hat=8, D_overlap=8, D_full=8
#
# pi1=0.10, i_rep=0
# # fMC: avg. MC samples = 20000, time=4.26s
#
# # AMT: avg. MC samples = 1253.0, time=0.07s
# # D_hat=55, D_overlap=55, D_full=55
#
# # sMC50: avg. MC samples = 1373.6, time=0.46s
# # D_hat=54, D_overlap=54, D_full=55
#
# # sMC100: avg. MC samples = 1813.5, time=0.48s
# # D_hat=55, D_overlap=55, D_full=55
#
# pi1=0.10, i_rep=1
# # fMC: avg. MC samples = 20000, time=4.28s
#
# # AMT: avg. MC samples = 1262.3, time=0.09s
# # D_hat=53, D_overlap=53, D_full=53
#
# # sMC50: avg. MC samples = 1387.5, time=0.48s
# # D_hat=54, D_overlap=53, D_full=53
#
# # sMC100: avg. MC samples = 1827.3, time=0.50s
# # D_hat=53, D_overlap=53, D_full=53
#
# pi1=0.10, i_rep=2
# # fMC: avg. MC samples = 20000, time=4.39s
#
# # AMT: avg. MC samples = 1477.1, time=0.08s
# # D_hat=42, D_overlap=42, D_full=42
#
# # sMC50: avg. MC samples = 1281.1, time=0.50s
# # D_hat=41, D_overlap=41, D_full=42
#
# # sMC100: avg. MC samples = 1784.7, time=0.60s
# # D_hat=42, D_overlap=42, D_full=42
#
# pi1=0.10, i_rep=3
# # fMC: avg. MC samples = 20000, time=4.23s
#
# # AMT: avg. MC samples = 1122.8, time=0.09s
# # D_hat=62, D_overlap=62, D_full=62
#
# # sMC50: avg. MC samples = 1456.1, time=0.49s
# # D_hat=60, D_overlap=59, D_full=62
#
# # sMC100: avg. MC samples = 1891.1, time=0.50s
# # D_hat=62, D_overlap=62, D_full=62
#
# pi1=0.10, i_rep=4
# # fMC: avg. MC samples = 20000, time=4.35s
#
# # AMT: avg. MC samples = 1302.1, time=0.10s
# # D_hat=39, D_overlap=39, D_full=39
#
# # sMC50: avg. MC samples = 1222.0, time=0.52s
# # D_hat=38, D_overlap=38, D_full=39
#
# # sMC100: avg. MC samples = 1727.3, time=0.52s
# # D_hat=39, D_overlap=39, D_full=39
#
# pi1=0.15, i_rep=0
# # fMC: avg. MC samples = 20000, time=4.23s
#
# # AMT: avg. MC samples = 1540.6, time=0.11s
# # D_hat=76, D_overlap=76, D_full=76
#
# # sMC50: avg. MC samples = 1741.1, time=0.48s
# # D_hat=78, D_overlap=76, D_full=76
#
# # sMC100: avg. MC samples = 2251.3, time=0.48s
# # D_hat=76, D_overlap=75, D_full=76
#
# pi1=0.15, i_rep=1
# # fMC: avg. MC samples = 20000, time=4.14s
#
# # AMT: avg. MC samples = 1486.4, time=0.10s
# # D_hat=96, D_overlap=96, D_full=96
#
# # sMC50: avg. MC samples = 1957.8, time=0.48s
# # D_hat=95, D_overlap=95, D_full=96
#
# # sMC100: avg. MC samples = 2488.8, time=0.50s
# # D_hat=96, D_overlap=96, D_full=96
#
# pi1=0.15, i_rep=2
# # fMC: avg. MC samples = 20000, time=4.23s
#
# # AMT: avg. MC samples = 1632.3, time=0.11s
# # D_hat=88, D_overlap=88, D_full=88
#
# # sMC50: avg. MC samples = 1782.2, time=0.50s
# # D_hat=89, D_overlap=88, D_full=88
#
# # sMC100: avg. MC samples = 2368.9, time=0.50s
# # D_hat=88, D_overlap=88, D_full=88
#
# pi1=0.15, i_rep=3
# # fMC: avg. MC samples = 20000, time=4.05s
#
# # AMT: avg. MC samples = 1235.3, time=0.09s
# # D_hat=97, D_overlap=97, D_full=97
#
# # sMC50: avg. MC samples = 1919.3, time=0.44s
# # D_hat=97, D_overlap=96, D_full=97
#
# # sMC100: avg. MC samples = 2426.9, time=0.46s
# # D_hat=96, D_overlap=96, D_full=97
#
# pi1=0.15, i_rep=4
# # fMC: avg. MC samples = 20000, time=4.25s
#
# # AMT: avg. MC samples = 1482.7, time=0.11s
# # D_hat=96, D_overlap=96, D_full=96
#
# # sMC50: avg. MC samples = 1800.3, time=0.43s
# # D_hat=96, D_overlap=94, D_full=96
#
# # sMC100: avg. MC samples = 2392.0, time=0.43s
# # D_hat=96, D_overlap=95, D_full=96
#
# pi1=0.20, i_rep=0
# # fMC: avg. MC samples = 20000, time=4.08s
#
# # AMT: avg. MC samples = 1691.5, time=0.10s
# # D_hat=132, D_overlap=132, D_full=132
#
# # sMC50: avg. MC samples = 2298.1, time=0.43s
# # D_hat=137, D_overlap=132, D_full=132
#
# # sMC100: avg. MC samples = 2928.7, time=0.43s
# # D_hat=134, D_overlap=132, D_full=132
#
# pi1=0.20, i_rep=1
# # fMC: avg. MC samples = 20000, time=3.94s
#
# # AMT: avg. MC samples = 1586.6, time=0.09s
# # D_hat=151, D_overlap=151, D_full=151
#
# # sMC50: avg. MC samples = 2484.5, time=0.44s
# # D_hat=148, D_overlap=148, D_full=151
#
# # sMC100: avg. MC samples = 3119.0, time=0.46s
# # D_hat=146, D_overlap=146, D_full=151
#
# pi1=0.20, i_rep=2
# # fMC: avg. MC samples = 20000, time=3.98s
#
# # AMT: avg. MC samples = 1577.2, time=0.10s
# # D_hat=144, D_overlap=144, D_full=144
#
# # sMC50: avg. MC samples = 2310.0, time=0.48s
# # D_hat=143, D_overlap=141, D_full=144
#
# # sMC100: avg. MC samples = 2957.8, time=0.47s
# # D_hat=143, D_overlap=143, D_full=144
#
# pi1=0.20, i_rep=3
# # fMC: avg. MC samples = 20000, time=4.09s
#
# # AMT: avg. MC samples = 1430.6, time=0.09s
# # D_hat=135, D_overlap=135, D_full=135
#
# # sMC50: avg. MC samples = 2406.6, time=0.49s
# # D_hat=128, D_overlap=128, D_full=135
#
# # sMC100: avg. MC samples = 3008.2, time=0.47s
# # D_hat=135, D_overlap=134, D_full=135
#
# pi1=0.20, i_rep=4
# # fMC: avg. MC samples = 20000, time=4.10s
#
# # AMT: avg. MC samples = 1636.3, time=0.11s
# # D_hat=141, D_overlap=141, D_full=141
#
# # sMC50: avg. MC samples = 2309.7, time=0.48s
# # D_hat=132, D_overlap=132, D_full=141
#
# # sMC100: avg. MC samples = 2992.6, time=0.50s
# # D_hat=136, D_overlap=136, D_full=141
#
# pi1=0.25, i_rep=0
# # fMC: avg. MC samples = 20000, time=3.96s
#
# # AMT: avg. MC samples = 1653.7, time=0.10s
# # D_hat=187, D_overlap=187, D_full=187
#
# # sMC50: avg. MC samples = 2745.7, time=0.51s
# # D_hat=183, D_overlap=182, D_full=187
#
# # sMC100: avg. MC samples = 3491.0, time=0.45s
# # D_hat=178, D_overlap=178, D_full=187
#
# pi1=0.25, i_rep=1
# # fMC: avg. MC samples = 20000, time=3.95s
#
# # AMT: avg. MC samples = 1618.5, time=0.12s
# # D_hat=196, D_overlap=196, D_full=196
#
# # sMC50: avg. MC samples = 2969.4, time=0.52s
# # D_hat=190, D_overlap=190, D_full=196
#
# # sMC100: avg. MC samples = 3696.1, time=0.48s
# # D_hat=193, D_overlap=191, D_full=196
#
# pi1=0.25, i_rep=2
# # fMC: avg. MC samples = 20000, time=3.96s
#
# # AMT: avg. MC samples = 1534.2, time=0.10s
# # D_hat=184, D_overlap=184, D_full=184
#
# # sMC50: avg. MC samples = 2773.5, time=0.43s
# # D_hat=184, D_overlap=182, D_full=184
#
# # sMC100: avg. MC samples = 3492.2, time=0.43s
# # D_hat=181, D_overlap=181, D_full=184
#
# pi1=0.25, i_rep=3
# # fMC: avg. MC samples = 20000, time=3.89s
#
# # AMT: avg. MC samples = 1607.1, time=0.10s
# # D_hat=180, D_overlap=180, D_full=180
#
# # sMC50: avg. MC samples = 2943.6, time=0.46s
# # D_hat=176, D_overlap=175, D_full=180
#
# # sMC100: avg. MC samples = 3612.7, time=0.43s
# # D_hat=179, D_overlap=178, D_full=180
#
# pi1=0.25, i_rep=4
# # fMC: avg. MC samples = 20000, time=3.98s
#
# # AMT: avg. MC samples = 1825.4, time=0.10s
# # D_hat=187, D_overlap=187, D_full=187
#
# # sMC50: avg. MC samples = 2756.4, time=0.43s
# # D_hat=178, D_overlap=178, D_full=187
#
# # sMC100: avg. MC samples = 3569.2, time=0.43s
# # D_hat=181, D_overlap=181, D_full=187
#
# pi1=0.30, i_rep=0
# # fMC: avg. MC samples = 20000, time=4.06s
#
# # AMT: avg. MC samples = 1830.8, time=0.10s
# # D_hat=217, D_overlap=217, D_full=217
#
# # sMC50: avg. MC samples = 3127.2, time=0.42s
# # D_hat=221, D_overlap=217, D_full=217
#
# # sMC100: avg. MC samples = 3954.8, time=0.42s
# # D_hat=219, D_overlap=217, D_full=217
#
# pi1=0.30, i_rep=1
# # fMC: avg. MC samples = 20000, time=3.93s
#
# # AMT: avg. MC samples = 1687.2, time=0.10s
# # D_hat=238, D_overlap=238, D_full=238
# # sMC50: avg. MC samples = 3402.7, time=0.43s
# # D_hat=235, D_overlap=233, D_full=238
#
# # sMC100: avg. MC samples = 4248.5, time=0.44s
# # D_hat=235, D_overlap=235, D_full=238
#
# pi1=0.30, i_rep=2
# # fMC: avg. MC samples = 20000, time=4.03s
#
# # AMT: avg. MC samples = 1610.6, time=0.10s
# # D_hat=222, D_overlap=222, D_full=222
#
# # sMC50: avg. MC samples = 3186.0, time=0.47s
# # D_hat=223, D_overlap=219, D_full=222
#
# # sMC100: avg. MC samples = 3980.4, time=0.47s
# # D_hat=225, D_overlap=221, D_full=222
#
# pi1=0.30, i_rep=3
# # fMC: avg. MC samples = 20000, time=4.05s
#
# # AMT: avg. MC samples = 1734.2, time=0.13s
# # D_hat=218, D_overlap=218, D_full=218
#
# # sMC50: avg. MC samples = 3436.4, time=0.49s
# # D_hat=219, D_overlap=216, D_full=218
#
# # sMC100: avg. MC samples = 4205.9, time=0.48s
# # D_hat=219, D_overlap=217, D_full=218
#
# pi1=0.30, i_rep=4
# # fMC: avg. MC samples = 20000, time=3.82s
#
# # AMT: avg. MC samples = 1867.7, time=0.10s
# # D_hat=231, D_overlap=231, D_full=231
#
# # sMC50: avg. MC samples = 3346.4, time=0.42s
# # D_hat=235, D_overlap=226, D_full=231
#
# # sMC100: avg. MC samples = 4230.6, time=0.42s
# # D_hat=229, D_overlap=228, D_full=231
#
# pi1=0.35, i_rep=0
# # fMC: avg. MC samples = 20000, time=3.79s
#
# # AMT: avg. MC samples = 1829.8, time=0.11s
# # D_hat=264, D_overlap=264, D_full=264
#
# # sMC50: avg. MC samples = 3648.9, time=0.41s
# # D_hat=260, D_overlap=259, D_full=264
#
# # sMC100: avg. MC samples = 4498.7, time=0.42s
# # D_hat=264, D_overlap=262, D_full=264
#
# pi1=0.35, i_rep=1
# # fMC: avg. MC samples = 20000, time=3.22s
#
# # AMT: avg. MC samples = 1652.3, time=0.09s
# # D_hat=287, D_overlap=287, D_full=287
#
# # sMC50: avg. MC samples = 3912.1, time=0.37s
# # D_hat=287, D_overlap=283, D_full=287
#
# # sMC100: avg. MC samples = 4844.2, time=0.36s
# # D_hat=286, D_overlap=283, D_full=287
#
# pi1=0.35, i_rep=2
# # fMC: avg. MC samples = 20000, time=3.14s
#
# # AMT: avg. MC samples = 1680.4, time=0.09s
# # D_hat=267, D_overlap=267, D_full=267
#
# # sMC50: avg. MC samples = 3657.3, time=0.36s
# # D_hat=262, D_overlap=260, D_full=267
#
# # sMC100: avg. MC samples = 4558.5, time=0.36s
# # D_hat=268, D_overlap=265, D_full=267
#
# pi1=0.35, i_rep=3
# # fMC: avg. MC samples = 20000, time=3.07s
#
# # AMT: avg. MC samples = 1811.1, time=0.09s
# # D_hat=269, D_overlap=269, D_full=269
#
# # sMC50: avg. MC samples = 3993.8, time=0.37s
# # D_hat=265, D_overlap=264, D_full=269
#
# # sMC100: avg. MC samples = 4821.5, time=0.36s
# # D_hat=264, D_overlap=263, D_full=269
#
# pi1=0.35, i_rep=4
# # fMC: avg. MC samples = 20000, time=3.62s
#
# # AMT: avg. MC samples = 1801.0, time=0.14s
# # D_hat=285, D_overlap=285, D_full=285
#
# # sMC50: avg. MC samples = 3913.6, time=0.50s
# # D_hat=282, D_overlap=279, D_full=285
#
# # sMC100: avg. MC samples = 4847.8, time=0.47s
# # D_hat=282, D_overlap=282, D_full=285
#
# pi1=0.40, i_rep=0
# # fMC: avg. MC samples = 20000, time=4.04s
#
# # AMT: avg. MC samples = 1895.7, time=0.12s
# # D_hat=311, D_overlap=311, D_full=311
#
# # sMC50: avg. MC samples = 4099.8, time=0.45s
# # D_hat=312, D_overlap=307, D_full=311
#
# # sMC100: avg. MC samples = 5081.6, time=0.47s
# # D_hat=308, D_overlap=307, D_full=311
#
# pi1=0.40, i_rep=1
# # fMC: avg. MC samples = 20000, time=3.91s
#
# # AMT: avg. MC samples = 1691.0, time=0.13s
# # D_hat=329, D_overlap=329, D_full=329
#
# # sMC50: avg. MC samples = 4404.3, time=0.49s
# # D_hat=331, D_overlap=326, D_full=329
#
# # sMC100: avg. MC samples = 5379.6, time=0.47s
# # D_hat=331, D_overlap=327, D_full=329
#
# pi1=0.40, i_rep=2
# # fMC: avg. MC samples = 20000, time=3.73s
#
# # AMT: avg. MC samples = 1689.2, time=0.13s
# # D_hat=314, D_overlap=314, D_full=314
#
# # sMC50: avg. MC samples = 4144.2, time=0.46s
# # D_hat=316, D_overlap=312, D_full=314
#
# # sMC100: avg. MC samples = 5120.7, time=0.44s
# # D_hat=316, D_overlap=314, D_full=314
#
# pi1=0.40, i_rep=3
# # fMC: avg. MC samples = 20000, time=3.83s
#
# # AMT: avg. MC samples = 1913.8, time=0.12s
# # D_hat=321, D_overlap=321, D_full=321
#
# # sMC50: avg. MC samples = 4545.0, time=0.45s
# # D_hat=318, D_overlap=313, D_full=321
#
# # sMC100: avg. MC samples = 5477.0, time=0.43s
# # D_hat=323, D_overlap=317, D_full=321
#
# pi1=0.40, i_rep=4
# # fMC: avg. MC samples = 20000, time=3.63s
#
# # AMT: avg. MC samples = 1750.9, time=0.12s
# # D_hat=339, D_overlap=339, D_full=339
#
# # sMC50: avg. MC samples = 4357.0, time=0.46s
# # D_hat=334, D_overlap=332, D_full=339
#
# # sMC100: avg. MC samples = 5420.6, time=0.46s
# # D_hat=335, D_overlap=334, D_full=339

# %% [markdown]
# # Generate figures

# %%
with open(output_file, 'rb')as f:
    res_dic = pickle.load(f)

# %%
# Generate the figures
output_fig_file = output_figure_folder+'/figure_alt_prop'
method_list = ['fmc', 'smc100', 'smc50', 'amt']
method_dic = {'fmc':'fMC', 'smc50':'sMC (r=50)', 
              'smc100':'sMC (r=100)', 'amt':'AMT'}
marker_list = ['o', 'v', '^', '*', 'h', 'd']
color_list = ['C0', 'C3', 'C1', 'C2', 'C5', 'C8']
plt.figure()
for i_method,method in enumerate(method_list):
    y_val = np.mean(res_dic[method]['n_MC_avg'], axis=1)
    temp = np.std(res_dic[method]['n_MC_avg'], axis=1) / np.sqrt(n_rep) * 1.96
    y_err = np.zeros([2, n_param], dtype=float) 
    y_err[0,:] = np.log10(y_val) - np.log10(y_val-temp) 
    y_err[1,:] = np.log10(y_val+temp) - np.log10(y_val)
    plt.errorbar(pi1_list, np.log10(y_val), yerr=y_err, label=method_dic[method],\
                 capsize=4, elinewidth = 1.5, linewidth=1.5,\
                 color = color_list[i_method], marker = marker_list[i_method],\
                 markersize = 6, alpha=0.8)
plt.grid()
plt.legend(fontsize=12, loc='upper left')
plt.xlabel('Alternative proportion', fontsize=12)
plt.ylabel('log10 average MC samples', fontsize=12)
plt.tight_layout()
plt.savefig(output_fig_file+'.png')
plt.savefig(output_fig_file+'.pdf')
plt.show()

# %%
# Generate the figures
marker_list = ['o', 'v', '^', '*', 'h', 'd']
color_list = ['C1', 'C2', 'C3', 'C0', 'C5', 'C8']
plt.figure()
for i_method,method in enumerate(method_list):
    y_val = np.mean(res_dic[method]['power'], axis=1)
    y_err = np.std(res_dic[method]['power'], axis=1) / np.sqrt(n_rep) * 1.96
    plt.errorbar(pi1_list, y_val, yerr=y_err, label=method,\
                 capsize=4, elinewidth = 1.5, linewidth=1.5,\
                 color = color_list[i_method], marker = marker_list[i_method],\
                 markersize = 6, alpha=0.8)
plt.legend()
plt.show()

# %%
# Generate the figures
marker_list = ['o', 'v', '^', '*', 'h', 'd']
color_list = ['C1', 'C2', 'C3', 'C0', 'C5', 'C8']
plt.figure()
for i_method,method in enumerate(method_list):
    y_val = np.mean(res_dic[method]['fdp'], axis=1)
    y_err = np.std(res_dic[method]['fdp'], axis=1) / np.sqrt(n_rep) * 1.96
    plt.errorbar(pi1_list, y_val, yerr=y_err, label=method,\
                 capsize=4, elinewidth = 1.5, linewidth=1.5,\
                 color = color_list[i_method], marker = marker_list[i_method],\
                 markersize = 6, alpha=0.8)
plt.legend()
plt.show()
