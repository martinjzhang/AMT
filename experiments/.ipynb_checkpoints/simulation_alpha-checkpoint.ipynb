# %%
import numpy as np
import scipy as sp
from scipy import stats
import matplotlib.pyplot as plt
import time
import amt.method as md
import amt.data_loader as dl
import pickle

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
output_folder = '/home/martin/adapative_MC_test/results/simulation'
output_figure_folder = '/home/martin/adapative_MC_test/figures/figure_simu'
output_file = output_folder + '/simulation_alpha.pickle'
n_hypothesis = 1000
n_rep = 5
alpha = 0.1
n_fMC = 10000
alpha_list = [0.05, 0.1, 0.15, 0.2, 0.25]
n_param = len(alpha_list)
method_list = ['fmc', 'smc50', 'smc100', 'amt']

# %% [markdown]
# # Simulation

# %%
res_dic = {}
for method in method_list:
    res_dic[method] = {}
    res_dic[method]['n_MC_avg'] = np.zeros([n_param, n_rep], dtype=float)
    res_dic[method]['power'] = np.zeros([n_param, n_rep], dtype=float)
    res_dic[method]['fdp'] = np.zeros([n_param, n_rep], dtype=float)
    res_dic[method]['time'] = np.zeros([n_param, n_rep], dtype=float)
    
for i_alpha,alpha in enumerate(alpha_list):
    for i_rep in range(n_rep):
        print('effect=%0.2f, i_rep=%d'%(alpha,i_rep))
        # Generate ground truth
        p_exact, h = dl.load_demo_data(n_hypothesis=n_hypothesis, pi1=0.2, 
                                       effect_size=2.5, random_state=i_rep)
        tau_exact = md.bh(p_exact, alpha=alpha)
        h_exact = (p_exact <= tau_exact)
        # fMC p-values and MC samples
        start_time = time.time()
        B, p_fmc, t_fmc = md.get_monte_carlo_sample(p_exact, n_permutation=n_fMC)
        tau_fmc = md.bh(p_fmc, alpha=alpha)
        h_fmc = (p_fmc <= tau_fmc)
        res_dic['fmc']['n_MC_avg'][i_alpha,i_rep] = n_fMC
        res_dic['fmc']['power'][i_alpha,i_rep] = np.sum(h_fmc&h)/np.sum(h)
        res_dic['fmc']['fdp'][i_alpha,i_rep] = np.sum(h_fmc&(~h))/np.sum(h_fmc)
        res_dic['fmc']['time'][i_alpha,i_rep] = time.time()-start_time
        print('# fMC: avg. MC samples = %d, time=%0.2fs'%(np.mean(n_fMC),
                                                          time.time()-start_time))
        print('')
        # AMT 
        start_time = time.time()
        p_hat_ub, p_hat, tau_hat, n_amt = md.amt(md.f_sample_dummy, B, n_hypothesis,
                                          alpha=alpha, n_fMC=n_fMC,
                                          verbose=False)
        h_amt = (p_hat_ub <= tau_hat)
        res_dic['amt']['n_MC_avg'][i_alpha,i_rep] = np.mean(n_amt)
        res_dic['amt']['power'][i_alpha,i_rep] = np.sum(h_amt&h)/np.sum(h)
        res_dic['amt']['fdp'][i_alpha,i_rep] = np.sum(h_amt&(~h))/np.sum(h_amt)
        res_dic['amt']['time'][i_alpha,i_rep] = time.time()-start_time
        print('# AMT: avg. MC samples = %0.1f, time=%0.2fs'%(np.mean(n_amt),
                                                             time.time()-start_time))
        print('# D_hat=%d, D_overlap=%d, D_full=%d'%(md.result_compare(h_amt, h_fmc)))
        print('')
        # smc50
        start_time = time.time()
        p_smc, n_smc = md.sMC(B, r=50)
        tau_smc = md.bh(p_smc, alpha=alpha)
        h_smc = (p_smc <= tau_smc)
        res_dic['smc50']['n_MC_avg'][i_alpha,i_rep] = np.mean(n_smc)
        res_dic['smc50']['power'][i_alpha,i_rep] = np.sum(h_smc&h)/np.sum(h)
        res_dic['smc50']['fdp'][i_alpha,i_rep] = np.sum(h_smc&(~h))/np.sum(h_smc)
        res_dic['smc50']['time'][i_alpha,i_rep] = time.time()-start_time
        print('# sMC50: avg. MC samples = %0.1f, time=%0.2fs'%(np.mean(n_smc),
                                                             time.time()-start_time))
        print('# D_hat=%d, D_overlap=%d, D_full=%d'%(md.result_compare(h_smc, h_fmc)))
        print('')
        # smc100
        start_time = time.time()
        p_smc, n_smc = md.sMC(B, r=100)
        tau_smc = md.bh(p_smc, alpha=alpha)
        h_smc = (p_smc <= tau_smc)
        res_dic['smc100']['n_MC_avg'][i_alpha,i_rep] = np.mean(n_smc)
        res_dic['smc100']['power'][i_alpha,i_rep] = np.sum(h_smc&h)/np.sum(h)
        res_dic['smc100']['fdp'][i_alpha,i_rep] = np.sum(h_smc&(~h))/np.sum(h_smc)
        res_dic['smc100']['time'][i_alpha,i_rep] = time.time()-start_time
        print('# sMC100: avg. MC samples = %0.1f, time=%0.2fs'%(np.mean(n_smc),
                                                             time.time()-start_time))
        print('# D_hat=%d, D_overlap=%d, D_full=%d'%(md.result_compare(h_smc, h_fmc)))
        print('')
with open(output_file, "wb") as f:
    pickle.dump(res_dic, f)
# Out:
# effect=0.05, i_rep=0
# # fMC: avg. MC samples = 10000, time=2.07s
#
# # AMT: avg. MC samples = 1461.8, time=0.10s
# # D_hat=92, D_overlap=92, D_full=92
#
# # sMC50: avg. MC samples = 1464.6, time=0.18s
# # D_hat=92, D_overlap=92, D_full=92
#
# # sMC100: avg. MC samples = 1875.1, time=0.19s
# # D_hat=92, D_overlap=92, D_full=92
#
# effect=0.05, i_rep=1
# # fMC: avg. MC samples = 10000, time=2.02s
#
# # AMT: avg. MC samples = 1495.3, time=0.18s
# # D_hat=107, D_overlap=107, D_full=107
#
# # sMC50: avg. MC samples = 1561.7, time=0.17s
# # D_hat=108, D_overlap=107, D_full=107
#
# # sMC100: avg. MC samples = 1961.1, time=0.17s
# # D_hat=107, D_overlap=107, D_full=107
#
# effect=0.05, i_rep=2
# # fMC: avg. MC samples = 10000, time=2.18s
#
# # AMT: avg. MC samples = 1530.9, time=0.11s
# # D_hat=86, D_overlap=86, D_full=86
#
# # sMC50: avg. MC samples = 1474.8, time=0.21s
# # D_hat=86, D_overlap=86, D_full=86
#
# # sMC100: avg. MC samples = 1879.6, time=0.16s
# # D_hat=86, D_overlap=86, D_full=86
#
# effect=0.05, i_rep=3
# # fMC: avg. MC samples = 10000, time=2.11s
#
# # AMT: avg. MC samples = 1325.8, time=0.10s
# # D_hat=106, D_overlap=106, D_full=106
#
# # sMC50: avg. MC samples = 1498.1, time=0.17s
# # D_hat=105, D_overlap=105, D_full=106
#
# # sMC100: avg. MC samples = 1874.7, time=0.16s
# # D_hat=106, D_overlap=106, D_full=106
#
# effect=0.05, i_rep=4
# # fMC: avg. MC samples = 10000, time=2.09s
#
# # AMT: avg. MC samples = 1504.4, time=0.11s
# # D_hat=91, D_overlap=91, D_full=91
#
# # sMC50: avg. MC samples = 1494.0, time=0.17s
# # D_hat=91, D_overlap=91, D_full=91
#
# # sMC100: avg. MC samples = 1920.0, time=0.24s
# # D_hat=91, D_overlap=91, D_full=91
#
# effect=0.10, i_rep=0
# # fMC: avg. MC samples = 10000, time=2.34s
#
# # AMT: avg. MC samples = 1200.3, time=0.10s
# # D_hat=136, D_overlap=136, D_full=136
#
# # sMC50: avg. MC samples = 1464.6, time=0.17s
# # D_hat=137, D_overlap=135, D_full=136
#
# # sMC100: avg. MC samples = 1875.1, time=0.30s
# # D_hat=134, D_overlap=134, D_full=136
#
# effect=0.10, i_rep=1
# # fMC: avg. MC samples = 10000, time=2.24s
#
# # AMT: avg. MC samples = 1152.5, time=0.13s
# # D_hat=151, D_overlap=151, D_full=151
#
# # sMC50: avg. MC samples = 1561.7, time=0.16s
# # D_hat=148, D_overlap=148, D_full=151
#
# # sMC100: avg. MC samples = 1961.1, time=0.15s
# # D_hat=146, D_overlap=146, D_full=151
#
# effect=0.10, i_rep=2
# # fMC: avg. MC samples = 10000, time=2.07s
#
# # AMT: avg. MC samples = 1137.8, time=0.10s
# # D_hat=142, D_overlap=142, D_full=142
#
# # sMC50: avg. MC samples = 1474.8, time=0.17s
# # D_hat=143, D_overlap=140, D_full=142
#
# # sMC100: avg. MC samples = 1879.6, time=0.16s
# # D_hat=143, D_overlap=142, D_full=142
#
# effect=0.10, i_rep=3
# # fMC: avg. MC samples = 10000, time=2.04s
#
# # AMT: avg. MC samples = 1106.7, time=0.08s
# # D_hat=133, D_overlap=133, D_full=133
#
# # sMC50: avg. MC samples = 1498.1, time=0.14s
# # D_hat=128, D_overlap=128, D_full=133
#
# # sMC100: avg. MC samples = 1874.7, time=0.14s
# # D_hat=135, D_overlap=133, D_full=133
#
# effect=0.10, i_rep=4
# # fMC: avg. MC samples = 10000, time=1.96s
#
# # AMT: avg. MC samples = 1271.6, time=0.09s
# # D_hat=136, D_overlap=136, D_full=136
#
# # sMC50: avg. MC samples = 1494.0, time=0.14s
# # D_hat=132, D_overlap=131, D_full=136
#
# # sMC100: avg. MC samples = 1920.0, time=0.15s
# # D_hat=136, D_overlap=134, D_full=136
#
# effect=0.15, i_rep=0
# # fMC: avg. MC samples = 10000, time=1.88s
#
# # AMT: avg. MC samples = 1027.6, time=0.09s
# # D_hat=164, D_overlap=164, D_full=164
#
# # sMC50: avg. MC samples = 1464.6, time=0.16s
# # D_hat=163, D_overlap=162, D_full=164
#
# # sMC100: avg. MC samples = 1875.1, time=0.15s
# # D_hat=163, D_overlap=162, D_full=164
#
# effect=0.15, i_rep=1
# # fMC: avg. MC samples = 10000, time=1.87s
#
# # AMT: avg. MC samples = 973.9, time=0.08s
# # D_hat=177, D_overlap=177, D_full=177
#
# # sMC50: avg. MC samples = 1561.7, time=0.14s
# # D_hat=173, D_overlap=173, D_full=177
#
# # sMC100: avg. MC samples = 1961.1, time=0.15s
# # D_hat=172, D_overlap=172, D_full=177
#
# effect=0.15, i_rep=2
# # fMC: avg. MC samples = 10000, time=1.77s
#
# # AMT: avg. MC samples = 933.6, time=0.06s
# # D_hat=166, D_overlap=166, D_full=166
#
# # sMC50: avg. MC samples = 1474.8, time=0.13s
# # D_hat=163, D_overlap=162, D_full=166
#
# # sMC100: avg. MC samples = 1879.6, time=0.13s
# # D_hat=166, D_overlap=164, D_full=166
#
# effect=0.15, i_rep=3
# # fMC: avg. MC samples = 10000, time=1.58s
#
# # AMT: avg. MC samples = 1121.1, time=0.07s
# # D_hat=156, D_overlap=156, D_full=156
#
# # sMC50: avg. MC samples = 1498.1, time=0.14s
# # D_hat=151, D_overlap=151, D_full=156
#
# # sMC100: avg. MC samples = 1874.7, time=0.14s
# # D_hat=155, D_overlap=154, D_full=156
#
# effect=0.15, i_rep=4
# # fMC: avg. MC samples = 10000, time=1.67s
#
# # AMT: avg. MC samples = 1051.0, time=0.07s
# # D_hat=172, D_overlap=172, D_full=172
#
# # sMC50: avg. MC samples = 1494.0, time=0.13s
# # D_hat=172, D_overlap=168, D_full=172
#
# # sMC100: avg. MC samples = 1920.0, time=0.13s
# # D_hat=167, D_overlap=167, D_full=172
#
# effect=0.20, i_rep=0
# # fMC: avg. MC samples = 10000, time=2.00s
#
# # AMT: avg. MC samples = 939.2, time=0.09s
# # D_hat=188, D_overlap=188, D_full=188
#
# # sMC50: avg. MC samples = 1464.6, time=0.16s
# # D_hat=188, D_overlap=184, D_full=188
#
# # sMC100: avg. MC samples = 1875.1, time=0.16s
# # D_hat=184, D_overlap=183, D_full=188
#
# effect=0.20, i_rep=1
# # fMC: avg. MC samples = 10000, time=2.08s
#
# # AMT: avg. MC samples = 914.3, time=0.08s
# # D_hat=195, D_overlap=195, D_full=195
#
# # sMC50: avg. MC samples = 1561.7, time=0.15s
# # D_hat=195, D_overlap=191, D_full=195
#
# # sMC100: avg. MC samples = 1961.1, time=0.16s
# # D_hat=193, D_overlap=192, D_full=195
#
# effect=0.20, i_rep=2
# # fMC: avg. MC samples = 10000, time=2.11s
#
# # AMT: avg. MC samples = 843.2, time=0.08s
# # D_hat=183, D_overlap=183, D_full=183
#
# # sMC50: avg. MC samples = 1474.8, time=0.16s
# # D_hat=181, D_overlap=179, D_full=183
#
# # sMC100: avg. MC samples = 1879.6, time=0.21s
# # D_hat=184, D_overlap=182, D_full=183
#
# effect=0.20, i_rep=3
# # fMC: avg. MC samples = 10000, time=2.07s
#
# # AMT: avg. MC samples = 1072.0, time=0.10s
# # D_hat=191, D_overlap=191, D_full=191
#
# # sMC50: avg. MC samples = 1498.1, time=0.16s
# # D_hat=190, D_overlap=187, D_full=191
#
# # sMC100: avg. MC samples = 1874.7, time=0.17s
# # D_hat=192, D_overlap=188, D_full=191
#
# effect=0.20, i_rep=4
# # fMC: avg. MC samples = 10000, time=2.15s
#
# # AMT: avg. MC samples = 1039.3, time=0.10s
# # D_hat=190, D_overlap=190, D_full=190
#
# # sMC50: avg. MC samples = 1494.0, time=0.17s
# # D_hat=193, D_overlap=188, D_full=190
#
# # sMC100: avg. MC samples = 1920.0, time=0.18s
# # D_hat=192, D_overlap=189, D_full=190
#
# effect=0.25, i_rep=0
# # fMC: avg. MC samples = 10000, time=2.07s
#
# # AMT: avg. MC samples = 864.5, time=0.09s
# # D_hat=215, D_overlap=215, D_full=215
#
# # sMC50: avg. MC samples = 1464.6, time=0.22s
# # D_hat=218, D_overlap=214, D_full=215
#
# # sMC100: avg. MC samples = 1875.1, time=0.16s
# # D_hat=209, D_overlap=209, D_full=215
#
# effect=0.25, i_rep=1
# # fMC: avg. MC samples = 10000, time=2.08s
#
# # AMT: avg. MC samples = 899.3, time=0.12s
# # D_hat=217, D_overlap=217, D_full=217
#
# # sMC50: avg. MC samples = 1561.7, time=0.17s
# # D_hat=219, D_overlap=216, D_full=217
#
# # sMC100: avg. MC samples = 1961.1, time=0.16s
# # D_hat=216, D_overlap=215, D_full=217
#
# effect=0.25, i_rep=2
# # fMC: avg. MC samples = 10000, time=2.11s
#
# # AMT: avg. MC samples = 825.6, time=0.08s
# # D_hat=200, D_overlap=200, D_full=200
#
# # sMC50: avg. MC samples = 1474.8, time=0.16s
# # D_hat=199, D_overlap=196, D_full=200
#
# # sMC100: avg. MC samples = 1879.6, time=0.16s
# # D_hat=197, D_overlap=195, D_full=200
#
# effect=0.25, i_rep=3
# # fMC: avg. MC samples = 10000, time=2.07s
#
# # AMT: avg. MC samples = 896.3, time=0.09s
# # D_hat=220, D_overlap=220, D_full=220
#
# # sMC50: avg. MC samples = 1498.1, time=0.17s
# # D_hat=222, D_overlap=216, D_full=220
#
# # sMC100: avg. MC samples = 1874.7, time=0.17s
# # D_hat=226, D_overlap=219, D_full=220
#
# effect=0.25, i_rep=4
# # fMC: avg. MC samples = 10000, time=2.07s
#
# # AMT: avg. MC samples = 980.1, time=0.10s
# # D_hat=214, D_overlap=214, D_full=214
#
# # sMC50: avg. MC samples = 1494.0, time=0.17s
# # D_hat=222, D_overlap=210, D_full=214
#
# # sMC100: avg. MC samples = 1920.0, time=0.17s
# # D_hat=212, D_overlap=209, D_full=214

# %% [markdown]
# # Generate figures

# %%
with open(output_file, 'rb')as f:
    res_dic = pickle.load(f)

# %%
# Generate the figures
output_fig_file = output_figure_folder+'/figure_fdr'
method_list = ['fmc', 'smc100', 'smc50', 'amt']
method_dic = {'fmc':'fMC', 'smc50':'sMC (r=50)', 
              'smc100':'sMC (r=100)', 'amt':'AMT'}
marker_list = ['o', 'v', '^', '*', 'h', 'd']
color_list = ['C0', 'C3', 'C1', 'C2', 'C5', 'C8']
plt.figure()
for i_method,method in enumerate(method_list):
    y_val = np.mean(res_dic[method]['n_MC_avg'], axis=1)
    temp = np.std(res_dic[method]['n_MC_avg'], axis=1) / np.sqrt(n_rep) * 1.96
    y_err = np.zeros([2, n_param], dtype=float) 
    y_err[0,:] = np.log10(y_val) - np.log10(y_val-temp) 
    y_err[1,:] = np.log10(y_val+temp) - np.log10(y_val)
    plt.errorbar(alpha_list, np.log10(y_val), yerr=y_err, label=method_dic[method],\
                 capsize=4, elinewidth = 1.5, linewidth=1.5,\
                 color = color_list[i_method], marker = marker_list[i_method],\
                 markersize = 6, alpha=0.8)
# plt.yscale('log')
plt.grid()
y_val = [3, 3.25, 3.5, 3.75, 4]
y_tick = []
for y in y_val:
    temp_str = '%0.1e'%(10**y)
    y_tick.append(temp_str.replace('+0', ''))
plt.yticks(y_val, y_tick, rotation= 0, fontsize=12)
plt.legend(fontsize=12, loc='upper left')
plt.xlabel('Nominal FDR', fontsize=12)
# plt.ylabel('log10 average MC samples', fontsize=12)
plt.ylabel('Avg. MC samples per hypothesis', fontsize=12)

plt.tight_layout()
plt.savefig(output_fig_file+'.png')
plt.savefig(output_fig_file+'.pdf')
plt.show()

# %% [markdown]
# # Old code

# %%
# Generate the figures
marker_list = ['o', 'v', '^', '*', 'h', 'd']
color_list = ['C1', 'C2', 'C3', 'C0', 'C5', 'C8']
plt.figure()
for i_method,method in enumerate(method_list):
    y_val = np.mean(res_dic[method]['power'], axis=1)
    y_err = np.std(res_dic[method]['power'], axis=1) / np.sqrt(n_rep) * 1.96
    plt.errorbar(alpha_list, y_val, yerr=y_err, label=method,\
                 capsize=4, elinewidth = 1.5, linewidth=1.5,\
                 color = color_list[i_method], marker = marker_list[i_method],\
                 markersize = 6, alpha=0.8)
plt.legend()
plt.show()

# %%
# Generate the figures
marker_list = ['o', 'v', '^', '*', 'h', 'd']
color_list = ['C1', 'C2', 'C3', 'C0', 'C5', 'C8']
plt.figure()
for i_method,method in enumerate(method_list):
    y_val = np.mean(res_dic[method]['fdp'], axis=1)
    y_err = np.std(res_dic[method]['fdp'], axis=1) / np.sqrt(n_rep) * 1.96
    plt.errorbar(alpha_list, y_val, yerr=y_err, label=method,\
                 capsize=4, elinewidth = 1.5, linewidth=1.5,\
                 color = color_list[i_method], marker = marker_list[i_method],\
                 markersize = 6, alpha=0.8)
plt.legend()
plt.show()
