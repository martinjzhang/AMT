# %%
import numpy as np
import scipy as sp
from scipy import stats
import matplotlib.pyplot as plt
import time
import amt.method as md
import amt.data_loader as dl
import pickle

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
output_folder = '../../results/simulation'
output_figure_folder = '../../figures/figure_simu'
output_file = output_folder + '/simulation_effect.pickle'
n_hypothesis = 1000
n_rep = 5
alpha = 0.1
n_fMC = 10000
effect_list = [1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5]
n_param = len(effect_list)
method_list = ['fmc', 'smc50', 'smc100', 'amt']

# %% [markdown]
# # Simulation

# %%
res_dic = {}
for method in method_list:
    res_dic[method] = {}
    res_dic[method]['n_MC_avg'] = np.zeros([n_param, n_rep], dtype=float)
    res_dic[method]['power'] = np.zeros([n_param, n_rep], dtype=float)
    res_dic[method]['fdp'] = np.zeros([n_param, n_rep], dtype=float)
    res_dic[method]['time'] = np.zeros([n_param, n_rep], dtype=float)
    
for i_effect,effect in enumerate(effect_list):
    for i_rep in range(n_rep):
        print('effect=%0.2f, i_rep=%d'%(effect,i_rep))
        # Generate ground truth
        p_exact, h = dl.load_demo_data(n_hypothesis=n_hypothesis, pi1=0.2, 
                                       effect_size=effect, random_state=i_rep)
        tau_exact = md.bh(p_exact, alpha=alpha)
        h_exact = (p_exact <= tau_exact)
        # fMC p-values and MC samples
        start_time = time.time()
        B, p_fmc, t_fmc = md.get_monte_carlo_sample(p_exact, n_permutation=n_fMC)
        tau_fmc = md.bh(p_fmc, alpha=alpha)
        h_fmc = (p_fmc <= tau_fmc)
        res_dic['fmc']['n_MC_avg'][i_effect,i_rep] = n_fMC
        res_dic['fmc']['power'][i_effect,i_rep] = np.sum(h_fmc&h)/np.sum(h)
        res_dic['fmc']['fdp'][i_effect,i_rep] = np.sum(h_fmc&(~h))/np.sum(h_fmc)
        res_dic['fmc']['time'][i_effect,i_rep] = time.time()-start_time
        print('# fMC: avg. MC samples = %d, time=%0.2fs'%(np.mean(n_fMC),
                                                          time.time()-start_time))
        print('')
        # AMT 
        start_time = time.time()
        p_hat_ub, p_hat_lb, p_hat, tau_hat, n_amt = md.amt(md.f_sample_dummy, B, n_hypothesis,
                                          alpha=alpha, n_fMC=n_fMC,
                                          verbose=False)
        h_amt = (p_hat_ub <= tau_hat)
        res_dic['amt']['n_MC_avg'][i_effect,i_rep] = np.mean(n_amt)
        res_dic['amt']['power'][i_effect,i_rep] = np.sum(h_amt&h)/np.sum(h)
        res_dic['amt']['fdp'][i_effect,i_rep] = np.sum(h_amt&(~h))/np.sum(h_amt)
        res_dic['amt']['time'][i_effect,i_rep] = time.time()-start_time
        print('# AMT: avg. MC samples = %0.1f, time=%0.2fs'%(np.mean(n_amt),
                                                             time.time()-start_time))
        print('# D_hat=%d, D_overlap=%d, D_full=%d'%(md.result_compare(h_amt, h_fmc)))
        print('')
        # smc50
        start_time = time.time()
        p_smc, n_smc = md.sMC(B, r=50)
        tau_smc = md.bh(p_smc, alpha=alpha)
        h_smc = (p_smc <= tau_smc)
        res_dic['smc50']['n_MC_avg'][i_effect,i_rep] = np.mean(n_smc)
        res_dic['smc50']['power'][i_effect,i_rep] = np.sum(h_smc&h)/np.sum(h)
        res_dic['smc50']['fdp'][i_effect,i_rep] = np.sum(h_smc&(~h))/np.sum(h_smc)
        res_dic['smc50']['time'][i_effect,i_rep] = time.time()-start_time
        print('# sMC50: avg. MC samples = %0.1f, time=%0.2fs'%(np.mean(n_smc),
                                                             time.time()-start_time))
        print('# D_hat=%d, D_overlap=%d, D_full=%d'%(md.result_compare(h_smc, h_fmc)))
        print('')
        # smc100
        start_time = time.time()
        p_smc, n_smc = md.sMC(B, r=100)
        tau_smc = md.bh(p_smc, alpha=alpha)
        h_smc = (p_smc <= tau_smc)
        res_dic['smc100']['n_MC_avg'][i_effect,i_rep] = np.mean(n_smc)
        res_dic['smc100']['power'][i_effect,i_rep] = np.sum(h_smc&h)/np.sum(h)
        res_dic['smc100']['fdp'][i_effect,i_rep] = np.sum(h_smc&(~h))/np.sum(h_smc)
        res_dic['smc100']['time'][i_effect,i_rep] = time.time()-start_time
        print('# sMC100: avg. MC samples = %0.1f, time=%0.2fs'%(np.mean(n_smc),
                                                             time.time()-start_time))
        print('# D_hat=%d, D_overlap=%d, D_full=%d'%(md.result_compare(h_smc, h_fmc)))
        print('')
with open(output_file, "wb") as f:
    pickle.dump(res_dic, f)
# Out:
# effect=1.00, i_rep=0
# /home/martin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:24: RuntimeWarning: invalid value encountered in long_scalars
# /home/martin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:37: RuntimeWarning: invalid value encountered in long_scalars
# /home/martin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:50: RuntimeWarning: invalid value encountered in long_scalars
# # fMC: avg. MC samples = 10000, time=2.02s
#
# # AMT: avg. MC samples = 358.2, time=0.05s
# # D_hat=0, D_overlap=0, D_full=0
#
# # sMC50: avg. MC samples = 513.5, time=0.14s
# # D_hat=0, D_overlap=0, D_full=0
# /home/martin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:63: RuntimeWarning: invalid value encountered in long_scalars
# # sMC100: avg. MC samples = 840.7, time=0.14s
# # D_hat=0, D_overlap=0, D_full=0
#
# effect=1.00, i_rep=1
# # fMC: avg. MC samples = 10000, time=2.00s
#
# # AMT: avg. MC samples = 329.4, time=0.04s
# # D_hat=3, D_overlap=3, D_full=3
#
# # sMC50: avg. MC samples = 489.7, time=0.14s
# # D_hat=3, D_overlap=3, D_full=3
#
# # sMC100: avg. MC samples = 816.0, time=0.14s
# # D_hat=3, D_overlap=3, D_full=3
#
# effect=1.00, i_rep=2
# # fMC: avg. MC samples = 10000, time=1.97s
#
# # AMT: avg. MC samples = 389.6, time=0.04s
# # D_hat=4, D_overlap=4, D_full=4
#
# # sMC50: avg. MC samples = 518.9, time=0.14s
# # D_hat=4, D_overlap=4, D_full=4
#
# # sMC100: avg. MC samples = 831.5, time=0.14s
# # D_hat=4, D_overlap=4, D_full=4
#
# effect=1.00, i_rep=3
# # fMC: avg. MC samples = 10000, time=2.02s
#
# # AMT: avg. MC samples = 385.2, time=0.05s
# # D_hat=0, D_overlap=0, D_full=0
#
# # sMC50: avg. MC samples = 542.7, time=0.14s
# # D_hat=0, D_overlap=0, D_full=0
#
# # sMC100: avg. MC samples = 907.5, time=0.14s
# # D_hat=0, D_overlap=0, D_full=0
#
# effect=1.00, i_rep=4
# # fMC: avg. MC samples = 10000, time=2.01s
#
# # AMT: avg. MC samples = 313.1, time=0.04s
# # D_hat=1, D_overlap=1, D_full=1
#
# # sMC50: avg. MC samples = 479.9, time=0.14s
# # D_hat=1, D_overlap=1, D_full=1
#
# # sMC100: avg. MC samples = 817.7, time=0.14s
# # D_hat=1, D_overlap=1, D_full=1
#
# effect=1.50, i_rep=0
# # fMC: avg. MC samples = 10000, time=1.99s
#
# # AMT: avg. MC samples = 707.6, time=0.05s
# # D_hat=20, D_overlap=20, D_full=20
#
# # sMC50: avg. MC samples = 733.7, time=0.14s
# # D_hat=20, D_overlap=20, D_full=20
#
# # sMC100: avg. MC samples = 1109.3, time=0.14s
# # D_hat=20, D_overlap=20, D_full=20
#
# effect=1.50, i_rep=1
# # fMC: avg. MC samples = 10000, time=1.98s
#
# # AMT: avg. MC samples = 687.7, time=0.06s
# # D_hat=18, D_overlap=18, D_full=18
#
# # sMC50: avg. MC samples = 746.0, time=0.14s
# # D_hat=18, D_overlap=18, D_full=18
#
# # sMC100: avg. MC samples = 1154.7, time=0.14s
# # D_hat=18, D_overlap=18, D_full=18
#
# effect=1.50, i_rep=2
# # fMC: avg. MC samples = 10000, time=2.14s
#
# # AMT: avg. MC samples = 695.8, time=0.06s
# # D_hat=18, D_overlap=18, D_full=18
#
# # sMC50: avg. MC samples = 730.3, time=0.15s
# # D_hat=18, D_overlap=18, D_full=18
#
# # sMC100: avg. MC samples = 1112.3, time=0.15s
# # D_hat=18, D_overlap=18, D_full=18
#
# effect=1.50, i_rep=3
# # fMC: avg. MC samples = 10000, time=1.95s
#
# # AMT: avg. MC samples = 857.4, time=0.06s
# # D_hat=20, D_overlap=20, D_full=20
#
# # sMC50: avg. MC samples = 829.9, time=0.14s
# # D_hat=20, D_overlap=20, D_full=20
#
# # sMC100: avg. MC samples = 1225.9, time=0.14s
# # D_hat=20, D_overlap=20, D_full=20
#
# effect=1.50, i_rep=4
# # fMC: avg. MC samples = 10000, time=2.00s
#
# # AMT: avg. MC samples = 581.4, time=0.05s
# # D_hat=3, D_overlap=3, D_full=3
#
# # sMC50: avg. MC samples = 696.2, time=0.14s
# # D_hat=3, D_overlap=3, D_full=3
#
# # sMC100: avg. MC samples = 1116.2, time=0.14s
# # D_hat=3, D_overlap=3, D_full=3
#
# effect=2.00, i_rep=0
# # fMC: avg. MC samples = 10000, time=1.94s
#
# # AMT: avg. MC samples = 1195.2, time=0.08s
# # D_hat=53, D_overlap=53, D_full=53
#
# # sMC50: avg. MC samples = 1042.6, time=0.14s
# # D_hat=54, D_overlap=53, D_full=53
#
# # sMC100: avg. MC samples = 1486.3, time=0.16s
# # D_hat=53, D_overlap=53, D_full=53
#
# effect=2.00, i_rep=1
# # fMC: avg. MC samples = 10000, time=1.95s
#
# # AMT: avg. MC samples = 1232.0, time=0.08s
# # D_hat=73, D_overlap=73, D_full=73
#
# # sMC50: avg. MC samples = 1144.5, time=0.14s
# # D_hat=78, D_overlap=73, D_full=73
#
# # sMC100: avg. MC samples = 1572.7, time=0.14s
# # D_hat=73, D_overlap=73, D_full=73
#
# effect=2.00, i_rep=2
# # fMC: avg. MC samples = 10000, time=1.91s
#
# # AMT: avg. MC samples = 1211.2, time=0.07s
# # D_hat=57, D_overlap=57, D_full=57
#
# # sMC50: avg. MC samples = 1078.4, time=0.14s
# # D_hat=57, D_overlap=57, D_full=57
#
# # sMC100: avg. MC samples = 1500.0, time=0.14s
# # D_hat=57, D_overlap=57, D_full=57
#
# effect=2.00, i_rep=3
# # fMC: avg. MC samples = 10000, time=1.89s
#
# # AMT: avg. MC samples = 1122.2, time=0.07s
# # D_hat=79, D_overlap=79, D_full=79
#
# # sMC50: avg. MC samples = 1159.2, time=0.13s
# # D_hat=80, D_overlap=79, D_full=79
#
# # sMC100: avg. MC samples = 1551.7, time=0.13s
# # D_hat=79, D_overlap=79, D_full=79
#
# effect=2.00, i_rep=4
# # fMC: avg. MC samples = 10000, time=1.88s
#
# # AMT: avg. MC samples = 1287.2, time=0.08s
# # D_hat=56, D_overlap=56, D_full=56
#
# # sMC50: avg. MC samples = 1067.4, time=0.15s
# # D_hat=56, D_overlap=56, D_full=56
#
# # sMC100: avg. MC samples = 1525.7, time=0.17s
# # D_hat=56, D_overlap=56, D_full=56
#
# effect=2.50, i_rep=0
# # fMC: avg. MC samples = 10000, time=1.81s
#
# # AMT: avg. MC samples = 1200.3, time=0.08s
# # D_hat=136, D_overlap=136, D_full=136
#
# # sMC50: avg. MC samples = 1464.6, time=0.15s
# # D_hat=137, D_overlap=135, D_full=136
#
# # sMC100: avg. MC samples = 1875.1, time=0.14s
# # D_hat=134, D_overlap=134, D_full=136
#
# effect=2.50, i_rep=1
# # fMC: avg. MC samples = 10000, time=1.59s
#
# # AMT: avg. MC samples = 1152.5, time=0.06s
# # D_hat=151, D_overlap=151, D_full=151
#
# # sMC50: avg. MC samples = 1561.7, time=0.12s
# # D_hat=148, D_overlap=148, D_full=151
#
# # sMC100: avg. MC samples = 1961.1, time=0.12s
# # D_hat=146, D_overlap=146, D_full=151
#
# effect=2.50, i_rep=2
# # fMC: avg. MC samples = 10000, time=1.57s
#
# # AMT: avg. MC samples = 1137.8, time=0.06s
# # D_hat=142, D_overlap=142, D_full=142
#
# # sMC50: avg. MC samples = 1474.8, time=0.12s
# # D_hat=143, D_overlap=140, D_full=142
#
# # sMC100: avg. MC samples = 1879.6, time=0.12s
# # D_hat=143, D_overlap=142, D_full=142
#
# effect=2.50, i_rep=3
# # fMC: avg. MC samples = 10000, time=1.70s
#
# # AMT: avg. MC samples = 1106.7, time=0.08s
# # D_hat=133, D_overlap=133, D_full=133
#
# # sMC50: avg. MC samples = 1498.1, time=0.14s
# # D_hat=128, D_overlap=128, D_full=133
#
# # sMC100: avg. MC samples = 1874.7, time=0.14s
# # D_hat=135, D_overlap=133, D_full=133
#
# effect=2.50, i_rep=4
# # fMC: avg. MC samples = 10000, time=1.90s
#
# # AMT: avg. MC samples = 1271.6, time=0.08s
# # D_hat=136, D_overlap=136, D_full=136
#
# # sMC50: avg. MC samples = 1494.0, time=0.14s
# # D_hat=132, D_overlap=131, D_full=136
#
# # sMC100: avg. MC samples = 1920.0, time=0.13s
# # D_hat=136, D_overlap=134, D_full=136
#
# effect=3.00, i_rep=0
# # fMC: avg. MC samples = 10000, time=1.84s
#
# # AMT: avg. MC samples = 1003.4, time=0.07s
# # D_hat=189, D_overlap=189, D_full=189
#
# # sMC50: avg. MC samples = 1831.7, time=0.14s
# # D_hat=189, D_overlap=186, D_full=189
#
# # sMC100: avg. MC samples = 2171.2, time=0.13s
# # D_hat=187, D_overlap=187, D_full=189
#
# effect=3.00, i_rep=1
# # fMC: avg. MC samples = 10000, time=1.87s
#
# # AMT: avg. MC samples = 931.9, time=0.07s
# # D_hat=184, D_overlap=184, D_full=184
#
# # sMC50: avg. MC samples = 1898.3, time=0.14s
# # D_hat=184, D_overlap=182, D_full=184
#
# # sMC100: avg. MC samples = 2199.8, time=0.14s
# # D_hat=183, D_overlap=183, D_full=184
#
# effect=3.00, i_rep=2
# # fMC: avg. MC samples = 10000, time=1.88s
#
# # AMT: avg. MC samples = 1013.3, time=0.08s
# # D_hat=178, D_overlap=178, D_full=178
#
# # sMC50: avg. MC samples = 1812.7, time=0.14s
# # D_hat=181, D_overlap=178, D_full=178
#
# # sMC100: avg. MC samples = 2146.7, time=0.13s
# # D_hat=177, D_overlap=177, D_full=178
#
# effect=3.00, i_rep=3
# # fMC: avg. MC samples = 10000, time=1.87s
#
# # AMT: avg. MC samples = 997.6, time=0.09s
# # D_hat=178, D_overlap=178, D_full=178
#
# # sMC50: avg. MC samples = 1815.2, time=0.16s
# # D_hat=179, D_overlap=178, D_full=178
#
# # sMC100: avg. MC samples = 2156.0, time=0.15s
# # D_hat=178, D_overlap=178, D_full=178
#
# effect=3.00, i_rep=4
# # fMC: avg. MC samples = 10000, time=1.94s
#
# # AMT: avg. MC samples = 1030.1, time=0.09s
# # D_hat=187, D_overlap=187, D_full=187
#
# # sMC50: avg. MC samples = 1840.2, time=0.14s
# # D_hat=189, D_overlap=185, D_full=187
#
# # sMC100: avg. MC samples = 2200.5, time=0.15s
# # D_hat=189, D_overlap=187, D_full=187
#
# effect=3.50, i_rep=0
# # fMC: avg. MC samples = 10000, time=1.98s
#
# # AMT: avg. MC samples = 840.2, time=0.08s
# # D_hat=208, D_overlap=208, D_full=208
#
# # sMC50: avg. MC samples = 2073.1, time=0.18s
# # D_hat=209, D_overlap=208, D_full=208
#
# # sMC100: avg. MC samples = 2336.0, time=0.19s
# # D_hat=209, D_overlap=208, D_full=208
#
# effect=3.50, i_rep=1
# # fMC: avg. MC samples = 10000, time=1.92s
#
# # AMT: avg. MC samples = 817.1, time=0.07s
# # D_hat=204, D_overlap=204, D_full=204
#
# # sMC50: avg. MC samples = 2084.3, time=0.19s
# # D_hat=201, D_overlap=200, D_full=204
#
# # sMC100: avg. MC samples = 2333.8, time=0.19s
# # D_hat=203, D_overlap=202, D_full=204
#
# effect=3.50, i_rep=2
# # fMC: avg. MC samples = 10000, time=1.90s
#
# # AMT: avg. MC samples = 837.2, time=0.07s
# # D_hat=209, D_overlap=209, D_full=209
#
# # sMC50: avg. MC samples = 2051.7, time=0.15s
# # D_hat=209, D_overlap=208, D_full=209
#
# # sMC100: avg. MC samples = 2340.7, time=0.14s
# # D_hat=208, D_overlap=208, D_full=209
#
# effect=3.50, i_rep=3
# # fMC: avg. MC samples = 10000, time=1.89s
#
# # AMT: avg. MC samples = 862.7, time=0.08s
# # D_hat=198, D_overlap=198, D_full=198
#
# # sMC50: avg. MC samples = 2035.2, time=0.13s
# # D_hat=198, D_overlap=198, D_full=198
#
# # sMC100: avg. MC samples = 2302.0, time=0.13s
# # D_hat=198, D_overlap=198, D_full=198
#
# effect=3.50, i_rep=4
# # fMC: avg. MC samples = 10000, time=2.04s
#
# # AMT: avg. MC samples = 885.3, time=0.09s
# # D_hat=208, D_overlap=208, D_full=208
#
# # sMC50: avg. MC samples = 2073.9, time=0.15s
# # D_hat=208, D_overlap=207, D_full=208
#
# # sMC100: avg. MC samples = 2362.1, time=0.15s
# # D_hat=206, D_overlap=206, D_full=208
#
# effect=4.00, i_rep=0
# # fMC: avg. MC samples = 10000, time=1.95s
#
# # AMT: avg. MC samples = 709.4, time=0.06s
# # D_hat=214, D_overlap=214, D_full=214
#
# # sMC50: avg. MC samples = 2179.6, time=0.16s
# # D_hat=214, D_overlap=214, D_full=214
#
# # sMC100: avg. MC samples = 2393.7, time=0.19s
# # D_hat=214, D_overlap=214, D_full=214
#
# effect=4.00, i_rep=1
# # fMC: avg. MC samples = 10000, time=1.88s
#
# # AMT: avg. MC samples = 680.1, time=0.07s
# # D_hat=212, D_overlap=212, D_full=212
#
# # sMC50: avg. MC samples = 2185.3, time=0.14s
# # D_hat=210, D_overlap=210, D_full=212
#
# # sMC100: avg. MC samples = 2394.6, time=0.14s
# # D_hat=211, D_overlap=211, D_full=212
#
# effect=4.00, i_rep=2
# # fMC: avg. MC samples = 10000, time=1.89s
#
# # AMT: avg. MC samples = 709.0, time=0.06s
# # D_hat=216, D_overlap=216, D_full=216
#
# # sMC50: avg. MC samples = 2202.0, time=0.14s
# # D_hat=217, D_overlap=216, D_full=216
#
# # sMC100: avg. MC samples = 2428.5, time=0.13s
# # D_hat=216, D_overlap=216, D_full=216
#
# effect=4.00, i_rep=3
# # fMC: avg. MC samples = 10000, time=2.06s
#
# # AMT: avg. MC samples = 819.1, time=0.07s
# # D_hat=207, D_overlap=207, D_full=207
#
# # sMC50: avg. MC samples = 2148.2, time=0.13s
# # D_hat=207, D_overlap=207, D_full=207
#
# # sMC100: avg. MC samples = 2388.2, time=0.13s
# # D_hat=207, D_overlap=207, D_full=207
#
# effect=4.00, i_rep=4
# # fMC: avg. MC samples = 10000, time=1.90s
#
# # AMT: avg. MC samples = 776.2, time=0.07s
# # D_hat=214, D_overlap=214, D_full=214
#
# # sMC50: avg. MC samples = 2187.3, time=0.14s
# # D_hat=216, D_overlap=214, D_full=214
#
# # sMC100: avg. MC samples = 2429.2, time=0.13s
# # D_hat=214, D_overlap=214, D_full=214
#
# effect=4.50, i_rep=0
# # fMC: avg. MC samples = 10000, time=1.91s
#
# # AMT: avg. MC samples = 686.3, time=0.06s
# # D_hat=215, D_overlap=215, D_full=215
#
# # sMC50: avg. MC samples = 2207.0, time=0.14s
# # D_hat=215, D_overlap=215, D_full=215
#
# # sMC100: avg. MC samples = 2406.3, time=0.13s
# # D_hat=215, D_overlap=215, D_full=215
#
# effect=4.50, i_rep=1
# # fMC: avg. MC samples = 10000, time=1.89s
#
# # AMT: avg. MC samples = 680.7, time=0.07s
# # D_hat=214, D_overlap=214, D_full=214
#
# # sMC50: avg. MC samples = 2207.9, time=0.15s
# # D_hat=212, D_overlap=212, D_full=214
#
# # sMC100: avg. MC samples = 2407.7, time=0.13s
# # D_hat=214, D_overlap=214, D_full=214
#
# effect=4.50, i_rep=2
# # fMC: avg. MC samples = 10000, time=1.99s
#
# # AMT: avg. MC samples = 675.0, time=0.07s
# # D_hat=221, D_overlap=221, D_full=221
#
# # sMC50: avg. MC samples = 2246.0, time=0.14s
# # D_hat=222, D_overlap=221, D_full=221
#
# # sMC100: avg. MC samples = 2459.5, time=0.14s
# # D_hat=221, D_overlap=221, D_full=221
#
# effect=4.50, i_rep=3
# # fMC: avg. MC samples = 10000, time=1.83s
#
# # AMT: avg. MC samples = 743.3, time=0.07s
# # D_hat=212, D_overlap=212, D_full=212
#
# # sMC50: avg. MC samples = 2212.0, time=0.14s
# # D_hat=212, D_overlap=212, D_full=212
#
# # sMC100: avg. MC samples = 2433.8, time=0.14s
# # D_hat=213, D_overlap=212, D_full=212
#
# effect=4.50, i_rep=4
# # fMC: avg. MC samples = 10000, time=1.89s
#
# # AMT: avg. MC samples = 745.0, time=0.07s
# # D_hat=219, D_overlap=219, D_full=219
#
# # sMC50: avg. MC samples = 2231.2, time=0.14s
# # D_hat=220, D_overlap=218, D_full=219
#
# # sMC100: avg. MC samples = 2463.4, time=0.13s
# # D_hat=219, D_overlap=218, D_full=219

# %% [markdown]
# # Generate figures

# %%
with open(output_file, 'rb')as f:
    res_dic = pickle.load(f)

# %%
# Generate the figures
output_fig_file = output_figure_folder+'/figure_effect'
# method_list = ['fmc', 'smc100', 'smc50', 'amt']
# method_dic = {'fmc':'fMC', 'smc50':'sMC (r=50)', 
#               'smc100':'sMC (r=100)', 'amt':'AMT'}
# marker_list = ['o', 'v', '^', '*', 'h', 'd']
# color_list = ['C0', 'C3', 'C1', 'C2', 'C5', 'C8']
method_list = ['fmc', 'smc100', 'amt']
method_dic = {'fmc':'fMC', 'smc50':'sMC (r=50)', 
              'smc100':'sMC', 'amt':'AMT'}
marker_list = ['o', 'v', '^', '*', 'h', 'd']
color_list = ['C0', 'C3', 'C2', 'C1', 'C5', 'C8']
plt.figure(figsize=(5,4))
# plt.figure()
for i_method,method in enumerate(method_list):
    y_val = np.mean(res_dic[method]['n_MC_avg'], axis=1)
    temp = np.std(res_dic[method]['n_MC_avg'], axis=1) / np.sqrt(n_rep) * 1.96
    y_err = np.zeros([2, n_param], dtype=float) 
    y_err[0,:] = np.log10(y_val) - np.log10(y_val-temp) 
    y_err[1,:] = np.log10(y_val+temp) - np.log10(y_val)
    plt.errorbar(effect_list, np.log10(y_val), yerr=y_err, label=method_dic[method],\
                 capsize=4, elinewidth = 1.5, linewidth=1.5,\
                 color = color_list[i_method], marker = marker_list[i_method],\
                 markersize = 6, alpha=0.8)
# plt.yscale('log')
plt.grid()
plt.xticks(fontsize=12)
y_val = [2.7, 3, 3.3, 3.7, 4]
y_tick = []
for y in y_val:
    temp_str = '%0.1e'%(10**y)
#     y_tick.append(temp_str.replace('+0', ''))
    y_tick.append(dtemp_str.replace('+0', '').replace('.0e','e'))
plt.yticks(y_val, y_tick, rotation= 0, fontsize=12)
plt.legend(fontsize=12, loc='upper left')
plt.xlabel('Effect size $\mu$', fontsize=14)
# plt.ylabel('log10 average MC samples', fontsize=12)
plt.ylabel('Avg. MC samples per hypothesis', fontsize=14)

plt.tight_layout()
plt.savefig(output_fig_file+'.png')
plt.savefig(output_fig_file+'.pdf')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-2c65d43a73e4> in <module>()
#      28     temp_str = '%0.1e'%(10**y)
#      29 #     y_tick.append(temp_str.replace('+0', ''))
# ---> 30     y_tick.append(dtemp_str.replace('+0', '').replace('.0e','e'))
#      31 plt.yticks(y_val, y_tick, rotation= 0, fontsize=12)
#      32 plt.legend(fontsize=12, loc='upper left')
#
# NameError: name 'dtemp_str' is not defined
